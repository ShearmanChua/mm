# %%
import os
from typing import Optional, List, Dict

from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk, scan, streaming_bulk

# %%
type_map = {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
def traverse_map (map_dict):
    original_map_dict = dict(map_dict)
    for k, v in map_dict.items():
        if isinstance(v, dict):
            traverse_map(v)
        else:
            try:
                map_dict[k] = {"type":TYPE_MAP[v.lower()]}
            except Exception as e:
                print(f'{e.__class__.__name__}: Key {v} not found in TYPE_MAP. Mapping not updated')
                return original_map_dict
    return map_dict

# %%
TYPE_MAP =  {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
user_map = {
    "name":"str",
    "age":"int",
    "education":{
        "primary":{
            "school":"str"
        },
        "secondary":"str",
        "tertiary":"str"
    }
}

# %%
final_map = {"mappings":{"properties":{}}}

# %%
updated_map = traverse_map(user_map)
# Out:
# KeyError: Key meow not found in TYPE_MAP. Mapping not updated

# %%
updated_map
# Out:
# {'name': {'type': 'text'},
#  'age': {'type': 'integer'},
#  'education': {'primary': {'school': 'meow'},
#   'secondary': {'type': 'text'},
#   'tertiary': {'type': 'text'}}}

# %%
TYPE_MAP =  {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
user_map = {
    "name":"str",
    "age":"int",
    "education":{
        "primary":{
            "school":"str"
        },
        "secondary":"str",
        "tertiary":"str"
    }
}

user_map = {
    "owner_name": "str",
    "owner_id": "str",
    "pets":{
        "cats": "int",
        "dogs": "int"
    }
}

# %%
MAX_BULK_SIZE=10000
class DocMgr():
    
    def __init__(self):
        self.url = f"https://{os.environ.get('ELASTICSEARCH_HOST')}:{os.environ.get('ELASTICSEARCH_C_PORT')}"
        self.username = os.environ.get('ELASTIC_USERNAME')
        self.password = os.environ.get('ELASTIC_PASSWORD')
        self.client = Elasticsearch(self.url, 
                                    verify_certs=False, 
                                    basic_auth=(self.username, self.password))
        
        self.consolidated_actions=[]

    def _check_data_type(self, var, var_type):
        try:
            assert type(var)==var_type
        except:
            return False
        return True
    
        
    def _check_valid_values(self, map_dict:dict) -> int:
        """
        Traverse mapping dictionary to ensure that all types are valid types within TYPE_MAP

        Args:
            map_dict (dict): Mapping to be checked

        Returns:
            int: 0 if there is invalid types, 1 otherwise

        """
        ret_val = 1
        for k, v in map_dict.items():
            if isinstance(v, dict):
                ret_val = self._check_valid_values(v)
            else:
                if not v in TYPE_MAP:
                    print(f"'{v}' type for '{k}' NOT FOUND")
                    return 0

        return ret_val * 1
    
    def _traverse_map (self, map_dict:Dict) -> Dict:
        """
        Traverse mapping dictionary to convert data type into framework specific type

        Args:
            map_dict (dict): Mapping to be used to create ES index

        Returns:
            dict: updated mapping dictionary

        """
        dictionary ={"properties":dict()}
        for k, v in map_dict.items():
            if isinstance(v, dict):
                dictionary['properties'][k]= self._traverse_map(v)
            else:
                dictionary['properties'][k]={"type":TYPE_MAP[v]}       
        return dictionary
    
    def _flush(self):
        errors = []
        list_of_es_ids = []
        for ok, item in streaming_bulk(self.client, self.consolidated_actions):
            if not ok:
                errors.append(item)
            else:
                list_of_es_ids.append(item['index']['_id'])
        print("List of faulty documents:", errors)
        self.consolidated_actions=[] # Reset List
        return list_of_es_ids
        
    def _flatten(self, d, parent_key='', sep='.'):
        """
        Flatten nested dictionary keys to dotted parameters because Elasticsearch. 
        """
        items = []
        for k, v in d.items():
            new_key = parent_key + sep + k if parent_key else k
            if isinstance(v, collections.MutableMapping):
                items.extend(flatten(v, new_key, sep=sep).items())
            else:
                items.append((new_key, v))
        return dict(items)
    
    def create_collection(self, collection_name: str, schema: Dict) -> Dict:
        """
        Create the index on ElasticSearch

        Args:
            collection_name (str): Index name of ES
            schema (dict): Mapping to be used to create ES index

        Returns:
            dict: response of error, or 200 if no errors caught
            
        """
        if not self._check_data_type(schema, dict):
            return {"response":"Type of 'schema' is not dict"}
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}

        mapping_validity = self._check_valid_values(schema)
        if not mapping_validity:
            return {"response": "KeyError: data type not found in TYPE_MAP"}
        updated_mapping = self._traverse_map(schema)
        try:
            self.client.indices.create(index=collection_name, mappings=updated_mapping)
        except Exception as e:
            return {"response":f"{e}"}
        return {"response":"200"}
    
    def delete_collection(self, collection_name: str) -> dict:
        """
        Create the index on ElasticSearch

        Args:
            collection_name (str): Index name of ES
            schema (dict): Mapping to be used to create ES index

        Returns:
            dict: response of error, or 200 if no errors caught

        """
        try:
            self.client.indices.delete(index=collection_name)
        except Exception as e:
            return {"response": f"{e}"}
        return {"response":"200"}
    
    def create_document(self, collection_name: str, documents: List[Dict], id_field: str=None) -> dict:
        """
        Upload document(s) in the specified index within ElasticSearch

        Args:
            collection_name (str): Index name of ES
            documents (list): A list of document objects to be ingested
            id_field (str, Optional): Specify the key amongst the document object to be the id field. If not specified, id will be generated by ES. 

        Returns:
            dict: response of error along with the faulty document, or code 200 along with the ids of ingested document if no errors caught

        """
        if not self._check_data_type(documents, list):
            return {"response":"Type of 'documents' is not dict"}
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not id_field is None:
            if not self._check_data_type(id_field, str):
                return {"response":"Type of 'id_field' is not str"}
        
        # If id_field is specified, verify that all documents possess the id_field. 
        if id_field != None:
            for doc in documents:
                if not id_field in doc.keys():
                    print("Fix document, or set 'id_field' to None. No documents uploaded.")
                    return {"response": "Fix document, or set 'id_field' to None. No documents uploaded.",
                           "error_doc": doc}
                try:
                    doc[id_field] = str(doc[id_field])
                except Exception as e:
                    return {"response": "id cannot be casted to String type. No documents uploaded.",
                           "error_doc": doc}
        all_id = []
        for doc in documents:
            action_dict={}
            action_dict['_op_type']= 'index'
            action_dict['_index']=collection_name
            if id_field != None:
                action_dict['_id']=doc[id_field]
                doc.pop(id_field)
            action_dict['_source']=doc
            self.consolidated_actions.append(action_dict)
            if len(self.consolidated_actions) == MAX_BULK_SIZE:
                all_id = all_id+self._flush()
        
        all_id = all_id+self._flush()
        
        return {"response":"200", "ids": all_id}
    
    def delete_document(self, collection_name: str, doc_id:str) -> dict:
        """
        Delete document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            doc_id (str): id of doc to be deleted

        Returns:
            dict: response of error along with the faulty document, or code 200 along with elastic API response

        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not self._check_data_type(doc_id, str):
            return {"response":"Type of 'doc_id' is not str"}
        
        # Check for document's existence     
        search_result = self.client.search(index=collection_name, query={"match":{"_id":doc_id}})
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"Document '{doc_id}' not found!"}
        
        try:
            resp = self.client.delete(index="meow", id=doc_id)
        except Exception as e:
            return {"response":f"{e.__class__.__name__}. Document Deletion failed"}
        
        return {"response":"200", "api_resp": resp}

    
    def update_document(self, collection_name: str, doc_id:str, properties: dict) -> dict:
        """
        Delete document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            doc_id (str): id of doc to be updated
            properties (dict): key and values of fields to be updated.

        Returns:
            dict: response of error along with the faulty document, or code 200 along with elastic API response

        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not self._check_data_type(doc_id, str):
            return {"response":"Type of 'doc_id' is not str"}
        if not self._check_data_type(properties, dict):
            return {"response":"Type of 'properties' is not dict"}
        
        
        # Check for document's existence     
        search_result = self.client.search(index=collection_name, query={"match":{"_id":doc_id}})
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"Document '{doc_id}' not found, create document first"}
        
        try:
            resp = self.client.update(index=collection_name, id=doc_id, doc=properties)
        except Exception as e:
            return {"response":f"{e.__class__.__name__}. Document Deletion failed"}
        
        return {"response":"200", "api_resp": resp}
    
    def read_document(self, collection_name: str, doc_id:str) -> dict:
        """
        Read document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            doc_id (str): id of doc to be deleted

        Returns:
            dict: response of error along with the faulty document, or code 200 along with the retrieved document

        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not self._check_data_type(doc_id, str):
            return {"response":"Type of 'doc_id' is not str"}
        
        # Check for document's existence     
        search_result = self.client.search(index=collection_name, query={"match":{"_id":doc_id}})
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"Document '{doc_id}' not found!"}
        
        doc_body = search_result['hits']['hits']
        
        return {"response":"200", "api_resp": doc_body}
    
    def query_collection(self, collection_name: str, field_value_dict:dict) -> dict:
        """
        Read document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            field_value_dict (dict): A dictionary with the field to be queried as the key, and the value to be queried as the value of the dictionary

        Returns:
            dict: response of error along with the faulty document, or code 200 along with the list of retrieved document

        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not self._check_data_type(field_value_dict, dict):
            return {"response":"Type of 'field_value_dict' is not dict"}
        
        # Check for document's existence
        field_value_dict = self._flatten(field_value_dict)
        search_result = self.client.search(index=collection_name, query={"match":field_value_dict})
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"No documents found."}
        
        docs = search_result['hits']['hits']
        
        return {"response":"200", "api_resp": docs}
    
    def custom_query(self, collection_name: str, query:dict) -> dict:
        """
        Read document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            query (dict): Custom query for ES users who are familiar with the query format

        Returns:
            dict: response of error along with the faulty document, or code 200 along with the list of retrieved document

        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        if not self._check_data_type(query, dict):
            return {"response":"Type of 'field_value_dict' is not dict"}
        
        # Check for document's existence
        search_result = self.client.search(index=collection_name, query=query)
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"No documents found."}
        
        docs = search_result['hits']['hits']
        
        return {"response":"200", "api_resp": docs}
    
    def get_all_documents(self, collection_name: str) -> dict:
        """
        Generator method to retrieve 

        Args:
            collection_name (str): Index name of ES
            
        Returns:
            Generator Object: Iterable object containing all documents within index specified by 
        """
        if not self._check_data_type(collection_name, str):
            return {"response":"Type of 'collection_name' is not str"}
        docs_response = scan(self.client, index=collection_name, query={"query":{"match_all":{}}})
        for item in docs_response:
            yield item

# %%
es_mgr = DocMgr()
# Out:
# /usr/local/lib/python3.8/site-packages/elasticsearch/_sync/client/__init__.py:395: SecurityWarning: Connecting to 'https://elasticsearch:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
create_res = es_mgr.create_collection(collection_name = "meow", schema = user_map)
print(create_res)
# Out:
# {'response': '200'}
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
del_res = es_mgr.delete_collection("meow")
print(del_res)
# Out:
# {'response': '200'}
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import random
import string

# printing lowercase

rand_data = []
user_map = {
    "owner_name": "str",
    "owner_id": "str",
    "cats": "int",
    "dogs": "int"
}

letters = string.ascii_lowercase
for i in range(1000):
    fake_data = {}
    fake_data["owner_name"] = ''.join(random.choice(letters) for i in range(10))
    fake_data['owner_id'] = i
    fake_data['pets']={}
    fake_data['pets']['cats'] = random.randint(0,5)
    fake_data['pets']['dogs'] = random.randint(0,5)
    rand_data.append(fake_data)

# %%
rand_data
# Out:
# [{'owner_name': 'lnrhlqcncv', 'owner_id': 0, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'clkwivkdhw', 'owner_id': 1, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'gstnqvfwtp', 'owner_id': 2, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'vkoodqrllo', 'owner_id': 3, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'vrowmvilat', 'owner_id': 4, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'yuxkhbetfh', 'owner_id': 5, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'ocmvaylszk', 'owner_id': 6, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'usnkgkzjyt', 'owner_id': 7, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'vpebtbldvw', 'owner_id': 8, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'asjxnxdoqn', 'owner_id': 9, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'hontqlnwoo', 'owner_id': 10, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'txmqlfkdke', 'owner_id': 11, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'qiaflgwrqr', 'owner_id': 12, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'doxtystqry', 'owner_id': 13, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'aubrezdwhk', 'owner_id': 14, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'rjavtsciam', 'owner_id': 15, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'grixpvzhmj', 'owner_id': 16, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'gmamwrpxuj', 'owner_id': 17, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'nfprhshykn', 'owner_id': 18, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'nsqpyievxs', 'owner_id': 19, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'oekpkuejbc', 'owner_id': 20, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'vnljigkuij', 'owner_id': 21, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'ylazhhnxee', 'owner_id': 22, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'blppqhutbl', 'owner_id': 23, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'fqdtrlimjl', 'owner_id': 24, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'fqkbtyzydj', 'owner_id': 25, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'qpyxpklavp', 'owner_id': 26, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'myoslmgokh', 'owner_id': 27, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'pigxupacue', 'owner_id': 28, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'wagrfowora', 'owner_id': 29, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'tlzvopqxxy', 'owner_id': 30, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'olzlgvkokh', 'owner_id': 31, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'kxfeeehjds', 'owner_id': 32, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'ybqgwlxjgo', 'owner_id': 33, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'ivkbmsddel', 'owner_id': 34, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'ljxgzhgfnb', 'owner_id': 35, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'pohvjerfpt', 'owner_id': 36, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'uzmlgshecx', 'owner_id': 37, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'spntypcgwn', 'owner_id': 38, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'nypljtytum', 'owner_id': 39, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'libjncsdul', 'owner_id': 40, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'ryzljmlmbk', 'owner_id': 41, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'nrwwgmqrms', 'owner_id': 42, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'docarprobg', 'owner_id': 43, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'uytngdqfis', 'owner_id': 44, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'wcgzuafwxl', 'owner_id': 45, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ykbriycorx', 'owner_id': 46, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'wjbjnqjxho', 'owner_id': 47, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'zvzupffxzc', 'owner_id': 48, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'mvkhoncwjp', 'owner_id': 49, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'gkuzbktjci', 'owner_id': 50, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'rnaewdrqdm', 'owner_id': 51, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'oejtmseksm', 'owner_id': 52, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'ydfxouhasj', 'owner_id': 53, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'jthgsmmmgn', 'owner_id': 54, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'ohbqdlrqhi', 'owner_id': 55, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'jivrppmnaq', 'owner_id': 56, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'zycfisacxr', 'owner_id': 57, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'dvsqltxgxt', 'owner_id': 58, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'uozjkdgyal', 'owner_id': 59, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'spmascbazv', 'owner_id': 60, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'kxuxexqzqn', 'owner_id': 61, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'krqwojuzam', 'owner_id': 62, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'iamkjeszcp', 'owner_id': 63, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'exgfowibix', 'owner_id': 64, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'ayjujqfcls', 'owner_id': 65, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'xovtzinwgu', 'owner_id': 66, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'xzmxlypcet', 'owner_id': 67, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'iecyapecon', 'owner_id': 68, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'uhmjxroxyv', 'owner_id': 69, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'tztbsbehra', 'owner_id': 70, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'prezjkplpe', 'owner_id': 71, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'btxvoxvnmz', 'owner_id': 72, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'irkixhipro', 'owner_id': 73, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'ixxnrgjwuc', 'owner_id': 74, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'jdaidzyuur', 'owner_id': 75, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'lashjffqpv', 'owner_id': 76, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'uehfvwrusc', 'owner_id': 77, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'fcgtrxayru', 'owner_id': 78, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'wxnvbkbmqf', 'owner_id': 79, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'nssetramgj', 'owner_id': 80, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'cusdeyybcy', 'owner_id': 81, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'tabtndchyx', 'owner_id': 82, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'zwhddcrlzk', 'owner_id': 83, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'xzygjyfizt', 'owner_id': 84, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'ttyzfkxkhr', 'owner_id': 85, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ayhknvumnh', 'owner_id': 86, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'qicrxpptmp', 'owner_id': 87, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'fsscxtvzcu', 'owner_id': 88, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'kbqidscuib', 'owner_id': 89, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'nuuiysgbpq', 'owner_id': 90, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'vwzkjgmbyo', 'owner_id': 91, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'exjmqlvgeb', 'owner_id': 92, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'xrmxtdjoce', 'owner_id': 93, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'qroiymannk', 'owner_id': 94, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'owoeofkdxh', 'owner_id': 95, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'hqvgvewknp', 'owner_id': 96, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'zkmqezlygv', 'owner_id': 97, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'rgkxglgmom', 'owner_id': 98, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'lozdnhaulw', 'owner_id': 99, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'ydebcpcyne', 'owner_id': 100, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'rpdtmqoskp', 'owner_id': 101, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'dexwziaatd', 'owner_id': 102, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'wlvzafovyn', 'owner_id': 103, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'zsxjtovske', 'owner_id': 104, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'eigiunrppq', 'owner_id': 105, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'klfraocula', 'owner_id': 106, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'bthqnmsdgr', 'owner_id': 107, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'jvsfwlhkyh', 'owner_id': 108, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'bkeqgtuqwu', 'owner_id': 109, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'rvxsdyxgxg', 'owner_id': 110, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'osudyvcecn', 'owner_id': 111, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'pvttlsruib', 'owner_id': 112, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'gpectgsesa', 'owner_id': 113, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'tubtytufgu', 'owner_id': 114, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'duiqigsfou', 'owner_id': 115, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'txrpholvva', 'owner_id': 116, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'wfkqlfrahy', 'owner_id': 117, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'lsmktjlyku', 'owner_id': 118, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'geqxnjmgeg', 'owner_id': 119, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'ocrgeingqg', 'owner_id': 120, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'zmsycsvykp', 'owner_id': 121, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'kebzfnpiwe', 'owner_id': 122, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'jbwkdxaapp', 'owner_id': 123, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'ldlwilguan', 'owner_id': 124, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'cjwrmjiupo', 'owner_id': 125, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'zuvcstqhnf', 'owner_id': 126, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'rofkoeeilq', 'owner_id': 127, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'dvsegntkow', 'owner_id': 128, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'kyjowyqbbp', 'owner_id': 129, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'fzlowitrox', 'owner_id': 130, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'evpvuqodpa', 'owner_id': 131, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'miyzwzunwr', 'owner_id': 132, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'qykmonpcur', 'owner_id': 133, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'sgrvgrphot', 'owner_id': 134, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'hhrnjqpvnv', 'owner_id': 135, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'uyvdxinsxm', 'owner_id': 136, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'obpmjtgxdb', 'owner_id': 137, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'tvlrozgiqk', 'owner_id': 138, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'czsdnndagc', 'owner_id': 139, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'hbuboepcmp', 'owner_id': 140, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'xvybtmsyra', 'owner_id': 141, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'lyelvbibln', 'owner_id': 142, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'uqtxlyralc', 'owner_id': 143, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'whgsgadsal', 'owner_id': 144, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'vhlrmdoyqg', 'owner_id': 145, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'acmgcfifim', 'owner_id': 146, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'xfdblsagpf', 'owner_id': 147, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'rxalavkdpd', 'owner_id': 148, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'gnvimzbytp', 'owner_id': 149, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'vlqusrqafu', 'owner_id': 150, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'luvrzoawfu', 'owner_id': 151, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'rzzhgeldsu', 'owner_id': 152, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'rfykesafjw', 'owner_id': 153, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'gkriyajyws', 'owner_id': 154, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'aybtquwyzf', 'owner_id': 155, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'rjtbpzuqku', 'owner_id': 156, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'ygijctxple', 'owner_id': 157, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'djbcbxillk', 'owner_id': 158, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'rinmxdkbkd', 'owner_id': 159, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'sthuqsthav', 'owner_id': 160, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'tjcvjgvvjw', 'owner_id': 161, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'atbpjpmbkq', 'owner_id': 162, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'ncbvgfmejq', 'owner_id': 163, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'petxvzcjga', 'owner_id': 164, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'ycgbwerisr', 'owner_id': 165, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'bhjyvupqiv', 'owner_id': 166, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'fsqxxfggwl', 'owner_id': 167, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'cmihublvtd', 'owner_id': 168, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'mmsaorlmnq', 'owner_id': 169, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'cpmpkkyhkz', 'owner_id': 170, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'jgjmrnamdd', 'owner_id': 171, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'jxcjcogtbl', 'owner_id': 172, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'xgnhqeyaaf', 'owner_id': 173, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'mygiggpvky', 'owner_id': 174, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ywyyzopaxx', 'owner_id': 175, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'csdrbzjpln', 'owner_id': 176, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'aealszmhwj', 'owner_id': 177, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'dugxbwtmmc', 'owner_id': 178, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'uqunmimxfp', 'owner_id': 179, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'rrjgoketom', 'owner_id': 180, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'hbreuuljuy', 'owner_id': 181, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'wyyhoikyjt', 'owner_id': 182, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'bynylkyrcb', 'owner_id': 183, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'kwyonvipwr', 'owner_id': 184, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'zghyyiismz', 'owner_id': 185, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'vrkmrvshyd', 'owner_id': 186, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'zldtdflisn', 'owner_id': 187, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'rtlfnurkbe', 'owner_id': 188, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'ahgmadhqps', 'owner_id': 189, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'qwkplxeelv', 'owner_id': 190, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'qinqzipytq', 'owner_id': 191, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'qcpxxwheno', 'owner_id': 192, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'mmiijqzfjy', 'owner_id': 193, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'hjnerlgvtv', 'owner_id': 194, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'cbyjrwtrwd', 'owner_id': 195, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'ziuzawvzgu', 'owner_id': 196, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'lmbtwbslwe', 'owner_id': 197, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'ydsefwibga', 'owner_id': 198, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'qtcsrxqbfs', 'owner_id': 199, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'zvtxdkqort', 'owner_id': 200, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'mfwkormece', 'owner_id': 201, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'fbevhwcitl', 'owner_id': 202, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'plpjlnfvvv', 'owner_id': 203, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'avuyklrazx', 'owner_id': 204, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'uwanflwddg', 'owner_id': 205, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'kethihkwbl', 'owner_id': 206, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'fpieilunub', 'owner_id': 207, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'nycanspzru', 'owner_id': 208, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'jafphfrarn', 'owner_id': 209, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'ptqglqjfyp', 'owner_id': 210, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'gnvdhlquyt', 'owner_id': 211, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'omgxyeqmnl', 'owner_id': 212, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'vmpyasybmj', 'owner_id': 213, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'ljdkziilzf', 'owner_id': 214, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'etjxyhzmod', 'owner_id': 215, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'crffijvnfe', 'owner_id': 216, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'kmrzlofvcu', 'owner_id': 217, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'sddondjmvg', 'owner_id': 218, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'yojdpswlor', 'owner_id': 219, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'ajgynssjes', 'owner_id': 220, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'patydjszoo', 'owner_id': 221, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'gxbhpozbgk', 'owner_id': 222, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'czrxfxdkgx', 'owner_id': 223, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'wvxhimobxl', 'owner_id': 224, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'jygkrypmqb', 'owner_id': 225, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'ainkenrjay', 'owner_id': 226, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'hrvcejlhja', 'owner_id': 227, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'vwvvqkdxus', 'owner_id': 228, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'txdwfpfmya', 'owner_id': 229, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'bgepqlsbja', 'owner_id': 230, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'iglaqihwkv', 'owner_id': 231, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'ymenrikdjh', 'owner_id': 232, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'kojdglrcoj', 'owner_id': 233, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'abnpfrejex', 'owner_id': 234, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'hvtrgibkxi', 'owner_id': 235, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'ciatcjwzmk', 'owner_id': 236, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'xctwrdbols', 'owner_id': 237, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'xqmofadrbd', 'owner_id': 238, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'tgkukkmtzm', 'owner_id': 239, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'fdbbydztri', 'owner_id': 240, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'xtghsuomka', 'owner_id': 241, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'pdncpqcgio', 'owner_id': 242, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'bhxfvzhlue', 'owner_id': 243, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'smvaihoiux', 'owner_id': 244, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'ltcmadhfqp', 'owner_id': 245, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'erufkmdqcj', 'owner_id': 246, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'riuyvgvlcb', 'owner_id': 247, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'aoqbhjubms', 'owner_id': 248, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'nzonvhmbge', 'owner_id': 249, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'jutvoebcws', 'owner_id': 250, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'chumgqmrgy', 'owner_id': 251, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'vxyomiscae', 'owner_id': 252, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'uqttbohtcb', 'owner_id': 253, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'ewzqqrhkmz', 'owner_id': 254, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'lfdlfjhcsv', 'owner_id': 255, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'ethiszzmmc', 'owner_id': 256, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'yyczaimkjd', 'owner_id': 257, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'rirvleavdz', 'owner_id': 258, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'adnsxxvrmi', 'owner_id': 259, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'usaidfywyz', 'owner_id': 260, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'ptmaevxnyx', 'owner_id': 261, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'wwexdenpdr', 'owner_id': 262, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'ulaedpdfvx', 'owner_id': 263, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'rsgphsqtzn', 'owner_id': 264, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'jgalxevnbu', 'owner_id': 265, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'slwttktxyv', 'owner_id': 266, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'eoegkrtvkg', 'owner_id': 267, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'pxuusbvmil', 'owner_id': 268, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'gzkxzcjbqm', 'owner_id': 269, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'iywnktxoqs', 'owner_id': 270, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'vbblhxzudr', 'owner_id': 271, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'ahojdpszkh', 'owner_id': 272, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'kpmsgllnjd', 'owner_id': 273, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'smdbksjgmk', 'owner_id': 274, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'ydidxvjfwn', 'owner_id': 275, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'chmzeeghqu', 'owner_id': 276, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'wzyxyohpao', 'owner_id': 277, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'ivmcyyyqma', 'owner_id': 278, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'chnxxohmpc', 'owner_id': 279, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'imtxastojj', 'owner_id': 280, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'fwjsgwclgd', 'owner_id': 281, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'dsyjnnmdww', 'owner_id': 282, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'oxhkbawyso', 'owner_id': 283, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'xbtpmwnocz', 'owner_id': 284, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'wsyhhxnpco', 'owner_id': 285, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ipwxijvcsg', 'owner_id': 286, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'vqyaliqubo', 'owner_id': 287, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'gczssajjab', 'owner_id': 288, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'joewkosdxo', 'owner_id': 289, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'bttcprweoj', 'owner_id': 290, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'vexznxeznm', 'owner_id': 291, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'uzmzihotpy', 'owner_id': 292, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'uxfhhxnbcj', 'owner_id': 293, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'tdtcxsytmw', 'owner_id': 294, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'nzhrjmrrrh', 'owner_id': 295, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'zvthpkethd', 'owner_id': 296, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'kkszkuezjp', 'owner_id': 297, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'skdyhgtlny', 'owner_id': 298, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'qgrvgdxfty', 'owner_id': 299, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'agvrzhjsbh', 'owner_id': 300, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'hsxxaairfd', 'owner_id': 301, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'lvlbvgxsds', 'owner_id': 302, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'deeuammjdi', 'owner_id': 303, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'ptljkpekmu', 'owner_id': 304, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'codsdmrsql', 'owner_id': 305, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'ynrmojevfr', 'owner_id': 306, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'palnnwmntc', 'owner_id': 307, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'mfjteifxiu', 'owner_id': 308, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'yicbuzfand', 'owner_id': 309, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'rjkfxusdth', 'owner_id': 310, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'kwkeyrcxmo', 'owner_id': 311, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'ovbloqentn', 'owner_id': 312, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'wtiklzbwbi', 'owner_id': 313, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'czfobxtbkp', 'owner_id': 314, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'owlatbfiyx', 'owner_id': 315, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'xbqurcbswi', 'owner_id': 316, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'zbpalyijjt', 'owner_id': 317, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'omcwtedxth', 'owner_id': 318, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'chqgwsqtux', 'owner_id': 319, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'pqkksguerq', 'owner_id': 320, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'swhwoeukqf', 'owner_id': 321, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'yzmannihbm', 'owner_id': 322, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'fcjoblubzk', 'owner_id': 323, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'hpdzzcxhzn', 'owner_id': 324, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'dizjqedkce', 'owner_id': 325, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'ckqqdxbqab', 'owner_id': 326, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'ljvvykyugk', 'owner_id': 327, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'gpqlgwmvqf', 'owner_id': 328, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'gufhxzdunm', 'owner_id': 329, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'nswwtskaoy', 'owner_id': 330, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'dpxxejpvkr', 'owner_id': 331, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'kzipkqtejg', 'owner_id': 332, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'sakphhxkui', 'owner_id': 333, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'dzzbeobftm', 'owner_id': 334, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'teujbmhpzm', 'owner_id': 335, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'iawlhucdou', 'owner_id': 336, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'eagtlviokc', 'owner_id': 337, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'qcufbedtmp', 'owner_id': 338, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'lwwmyadzdt', 'owner_id': 339, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'vhtkpqnbvh', 'owner_id': 340, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'fylmhqdiad', 'owner_id': 341, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'uqrvdnvxcg', 'owner_id': 342, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'ksiuqrtcpm', 'owner_id': 343, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'sdjkkrjwxr', 'owner_id': 344, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'zpdumxcmiv', 'owner_id': 345, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'gmapnttynf', 'owner_id': 346, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'mhnruixehq', 'owner_id': 347, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'gwecdaputd', 'owner_id': 348, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'kugyyqoyeo', 'owner_id': 349, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'manbcwhymt', 'owner_id': 350, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'rpjbsqxyfp', 'owner_id': 351, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'kwlgwltsht', 'owner_id': 352, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'adkzpbooqv', 'owner_id': 353, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'irjsltpeqs', 'owner_id': 354, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'sqardepxfz', 'owner_id': 355, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'mqqfteuhyb', 'owner_id': 356, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'hxguqqjwgn', 'owner_id': 357, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'dgqwvngckq', 'owner_id': 358, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'rurgqzgeyq', 'owner_id': 359, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'xocxpraiwj', 'owner_id': 360, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'tvfnqxjrkk', 'owner_id': 361, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'shmzfavzzv', 'owner_id': 362, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'esamkghgjk', 'owner_id': 363, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'pzmapjxzaw', 'owner_id': 364, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'xskpfwavdf', 'owner_id': 365, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'bgwkjpgvdm', 'owner_id': 366, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'lmpecfjgsd', 'owner_id': 367, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'bpbcsdyzem', 'owner_id': 368, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'trcyanzmhg', 'owner_id': 369, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'itqznjozss', 'owner_id': 370, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'nstmzossfe', 'owner_id': 371, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'aeupigcptm', 'owner_id': 372, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'gdqtjuacbh', 'owner_id': 373, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'wnbdrausod', 'owner_id': 374, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'xmrsvosfmr', 'owner_id': 375, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'eptbmebvim', 'owner_id': 376, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'xxlbtzfxlk', 'owner_id': 377, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'aiomlcryit', 'owner_id': 378, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'afqioudjpj', 'owner_id': 379, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'avfohqkklg', 'owner_id': 380, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'vlpklgevgi', 'owner_id': 381, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'perubpyiid', 'owner_id': 382, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'rwlorxgpdh', 'owner_id': 383, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'evwlwospzh', 'owner_id': 384, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'oeibtnuiyj', 'owner_id': 385, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'gllvekhomq', 'owner_id': 386, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'pdlfetyjlx', 'owner_id': 387, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'hyoamhhvtb', 'owner_id': 388, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'ewrxbzyzhk', 'owner_id': 389, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'hxzyocmekg', 'owner_id': 390, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'lcozewopvh', 'owner_id': 391, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'iodjquwbuv', 'owner_id': 392, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'lxgqgtcngq', 'owner_id': 393, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'iquxnvfwxc', 'owner_id': 394, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'lijtddmhoi', 'owner_id': 395, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'vzwahtnbqm', 'owner_id': 396, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'skeclrnapq', 'owner_id': 397, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'qfgmuqmjsf', 'owner_id': 398, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'qsccxckdke', 'owner_id': 399, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'syynrwzkkt', 'owner_id': 400, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'oictbaeouy', 'owner_id': 401, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'qfkkbngngc', 'owner_id': 402, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'asyrwyfcdd', 'owner_id': 403, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'qgtspajqkk', 'owner_id': 404, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'kcapivfmkh', 'owner_id': 405, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'dnfndqpynh', 'owner_id': 406, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'nobpxddlov', 'owner_id': 407, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'nzpefmsikl', 'owner_id': 408, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'gltsjvbmbb', 'owner_id': 409, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'ykfelbrzzu', 'owner_id': 410, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'pvwkwpubfq', 'owner_id': 411, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'qlakkioxix', 'owner_id': 412, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'oaahcstzth', 'owner_id': 413, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'gxqacmikpk', 'owner_id': 414, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'myedifxpys', 'owner_id': 415, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'iehajodirm', 'owner_id': 416, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'tszqjtlxrv', 'owner_id': 417, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'hgmjmbwjjw', 'owner_id': 418, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'yjsdlrliiy', 'owner_id': 419, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'jgnqfrxztj', 'owner_id': 420, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'thfrbsoojg', 'owner_id': 421, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'jhdgdlflof', 'owner_id': 422, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'acizlkcbow', 'owner_id': 423, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'qrorankhnb', 'owner_id': 424, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'dquthciuhu', 'owner_id': 425, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'wguycmswbg', 'owner_id': 426, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'hrcjaagpay', 'owner_id': 427, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'kdywljngsr', 'owner_id': 428, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'japcxvfxbx', 'owner_id': 429, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'wrpksxjlwa', 'owner_id': 430, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'pkcehttrxb', 'owner_id': 431, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'wrjwcatzfw', 'owner_id': 432, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'netlolutsf', 'owner_id': 433, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'uefuicoeec', 'owner_id': 434, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'rcamyivgvi', 'owner_id': 435, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'jmduesfkjt', 'owner_id': 436, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'fknvjnlswh', 'owner_id': 437, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'wqyebxqykh', 'owner_id': 438, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'jbqdqubjyi', 'owner_id': 439, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'pouirryjem', 'owner_id': 440, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'eowrunalou', 'owner_id': 441, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'nwpwpcubmp', 'owner_id': 442, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'swzxsdfaag', 'owner_id': 443, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'wxlnmoycee', 'owner_id': 444, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'dluiytnqoi', 'owner_id': 445, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'qvsbwlfzum', 'owner_id': 446, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'fpvmdwdjhj', 'owner_id': 447, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'ddgekkxdoh', 'owner_id': 448, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'echxtyjpnd', 'owner_id': 449, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'efxlxemqkc', 'owner_id': 450, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'bgsgpfblym', 'owner_id': 451, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'bjgrdvbgdw', 'owner_id': 452, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'hjtseyirsk', 'owner_id': 453, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'vtuozzntom', 'owner_id': 454, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'gfprkzqdcw', 'owner_id': 455, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'jdwgkrbtqe', 'owner_id': 456, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'ajoxuzfbzb', 'owner_id': 457, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'kwjipkkgvs', 'owner_id': 458, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'znpqvhfstf', 'owner_id': 459, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'cjbulaxlei', 'owner_id': 460, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'ozkuxzhkve', 'owner_id': 461, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'zkvdmhnacp', 'owner_id': 462, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'zstjzlbdsb', 'owner_id': 463, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'qkxgoeebyi', 'owner_id': 464, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'zexfkkavzm', 'owner_id': 465, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'endottvueu', 'owner_id': 466, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'kxyaolwofc', 'owner_id': 467, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'ndiomfskol', 'owner_id': 468, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'gwphhtklbt', 'owner_id': 469, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'mtlfjjoosf', 'owner_id': 470, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'qhwlbkjckj', 'owner_id': 471, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'idbgdfjqts', 'owner_id': 472, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'iirsdmsvmx', 'owner_id': 473, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'nkzrvupnag', 'owner_id': 474, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'ecascazpho', 'owner_id': 475, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'kavdwwnuph', 'owner_id': 476, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'wcijycswuo', 'owner_id': 477, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'krqzkrsxxx', 'owner_id': 478, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'vglfhrvmyd', 'owner_id': 479, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'hqvcevzkzo', 'owner_id': 480, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'ueyxxshjbs', 'owner_id': 481, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'oahcrjkuuh', 'owner_id': 482, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'frhjpcmmbp', 'owner_id': 483, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'wexmiafivf', 'owner_id': 484, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'zamgrfhbln', 'owner_id': 485, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'wbozefjgkc', 'owner_id': 486, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'yugagcqgvf', 'owner_id': 487, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'bfaepjxiqr', 'owner_id': 488, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'pioezevtko', 'owner_id': 489, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'rqoklouyzn', 'owner_id': 490, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'aneightvme', 'owner_id': 491, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'bmezecicvv', 'owner_id': 492, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'vtnvhueobl', 'owner_id': 493, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'xuecztpebc', 'owner_id': 494, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'bfzlzrwepl', 'owner_id': 495, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'pxebhbqqap', 'owner_id': 496, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'zxmkjpshsb', 'owner_id': 497, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'yvzuvkvfaq', 'owner_id': 498, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'qkfrvksfdq', 'owner_id': 499, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'fduoplbwqh', 'owner_id': 500, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'ivnmnugtxq', 'owner_id': 501, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'markyvjpue', 'owner_id': 502, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'ecgdvauoch', 'owner_id': 503, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'rmaeihcohw', 'owner_id': 504, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'dzhlmmdgwv', 'owner_id': 505, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'mgmwlpuftu', 'owner_id': 506, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'pccvvtwpxs', 'owner_id': 507, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'izbjgqxesi', 'owner_id': 508, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'cafzglbflx', 'owner_id': 509, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'txertcfjru', 'owner_id': 510, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'vburtjnkfv', 'owner_id': 511, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'xuqshamxee', 'owner_id': 512, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'wznzmntsig', 'owner_id': 513, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'hwdmhbncgh', 'owner_id': 514, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'hsvzlhajrt', 'owner_id': 515, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'yjghfvjvbh', 'owner_id': 516, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'nnekzdplig', 'owner_id': 517, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'cnaruievgk', 'owner_id': 518, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'edvpvusaua', 'owner_id': 519, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'famfdfzsow', 'owner_id': 520, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'rwifwbgjmd', 'owner_id': 521, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'bmwmhlztim', 'owner_id': 522, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'djkmbjkcxn', 'owner_id': 523, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'ippbaxrxwh', 'owner_id': 524, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'jseatygfep', 'owner_id': 525, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'whzgfuipju', 'owner_id': 526, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'ydttlteyst', 'owner_id': 527, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'fhxrsiafif', 'owner_id': 528, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'eshercglfx', 'owner_id': 529, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'icuikrwqqr', 'owner_id': 530, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'xzhbeqeoqb', 'owner_id': 531, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'czsozpczdf', 'owner_id': 532, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'rhqyxfeeht', 'owner_id': 533, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'hqapxoapgc', 'owner_id': 534, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'bxrswefrmo', 'owner_id': 535, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'pkvaumkqoi', 'owner_id': 536, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'dqwbsrcxab', 'owner_id': 537, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'ukksiiiftd', 'owner_id': 538, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'mlvrovgvxm', 'owner_id': 539, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'pkucuffogh', 'owner_id': 540, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'oolukswzdl', 'owner_id': 541, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'fyjmkxyiuk', 'owner_id': 542, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'auxxpfiqqo', 'owner_id': 543, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'hkwhakztwf', 'owner_id': 544, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'juwpeoedkj', 'owner_id': 545, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'hmfikppdha', 'owner_id': 546, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'gdnxjufeih', 'owner_id': 547, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'padwufpsfh', 'owner_id': 548, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'xakiacwlmg', 'owner_id': 549, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'wrgnyjwplv', 'owner_id': 550, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'qdtjbaojlk', 'owner_id': 551, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'ktrefzpxbo', 'owner_id': 552, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'rklymoiugb', 'owner_id': 553, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'nlbzoivrws', 'owner_id': 554, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'wtzwzeiyjm', 'owner_id': 555, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'fxgelnjspf', 'owner_id': 556, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'bxhamdnwdv', 'owner_id': 557, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'snsdgydkim', 'owner_id': 558, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'oaskrwcrye', 'owner_id': 559, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'lhppvboehg', 'owner_id': 560, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'kssgiqignz', 'owner_id': 561, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'kwhdyvqybx', 'owner_id': 562, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'zvjasuwczl', 'owner_id': 563, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'kfsjmjetdt', 'owner_id': 564, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'gqewpfvlpn', 'owner_id': 565, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'bwhnxnjenh', 'owner_id': 566, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'mtavosawvf', 'owner_id': 567, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'rvoltiylte', 'owner_id': 568, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'zyemnefzvd', 'owner_id': 569, 'pets': {'cats': 1, 'dogs': 1}},
#  {'owner_name': 'vgtryoxnkz', 'owner_id': 570, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'iqbewnjecw', 'owner_id': 571, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'yewglvdogw', 'owner_id': 572, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'riwrifheby', 'owner_id': 573, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'gwculavbqv', 'owner_id': 574, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'nxgwpevjrq', 'owner_id': 575, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'tukmjhrigt', 'owner_id': 576, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'ljlacxzlas', 'owner_id': 577, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'pvslqmhnrt', 'owner_id': 578, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'xfmjruymxl', 'owner_id': 579, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'csmddbwyco', 'owner_id': 580, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'roivmrqhxn', 'owner_id': 581, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'matfhoevkn', 'owner_id': 582, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'needoqiayc', 'owner_id': 583, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'riolxdvnru', 'owner_id': 584, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'niifrtejkm', 'owner_id': 585, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'ppttaekffo', 'owner_id': 586, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'qvtgsfvwdb', 'owner_id': 587, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'rvukjotwgm', 'owner_id': 588, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'ewezyggiee', 'owner_id': 589, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'szfcbslvkc', 'owner_id': 590, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'yqmrskzfbt', 'owner_id': 591, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'owukbcnjls', 'owner_id': 592, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'kltczdcunu', 'owner_id': 593, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'mpelxncqad', 'owner_id': 594, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'ockxhzftdd', 'owner_id': 595, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'rjngfdtder', 'owner_id': 596, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'ifygebyfzj', 'owner_id': 597, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'cbkvcikmwd', 'owner_id': 598, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'rmxxjadnwu', 'owner_id': 599, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'kmfkvtraug', 'owner_id': 600, 'pets': {'cats': 5, 'dogs': 4}},
# ...
#  {'owner_name': 'vbacbtmors', 'owner_id': 800, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'pbmhvnbcbl', 'owner_id': 801, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'rthsnoqadi', 'owner_id': 802, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'ercppxedxy', 'owner_id': 803, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'nuovnjqpbx', 'owner_id': 804, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'gpohxwnyad', 'owner_id': 805, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'plnltyhdkg', 'owner_id': 806, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'bgxtspfhpx', 'owner_id': 807, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'vqxioiynql', 'owner_id': 808, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'fkbpkiylgy', 'owner_id': 809, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'baazegxeox', 'owner_id': 810, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'pplfbpyxxq', 'owner_id': 811, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'gltlpetjrb', 'owner_id': 812, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'akyzakqzfp', 'owner_id': 813, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'hqlzfirgws', 'owner_id': 814, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'mvxrpcnaun', 'owner_id': 815, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'macjfpkdth', 'owner_id': 816, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'kgtnfbgfze', 'owner_id': 817, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'zaxbjdayat', 'owner_id': 818, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'tlsldqdsyv', 'owner_id': 819, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'vnwkidtgvb', 'owner_id': 820, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'yrknjmctsm', 'owner_id': 821, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'zptzhxviik', 'owner_id': 822, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'qraiasooit', 'owner_id': 823, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'dldyykmjze', 'owner_id': 824, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'mvpigpsfnf', 'owner_id': 825, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ttxhkwzwzw', 'owner_id': 826, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'tbxdjdynhy', 'owner_id': 827, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'askstgfycj', 'owner_id': 828, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'nsroovltjk', 'owner_id': 829, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'juiyqrqmdu', 'owner_id': 830, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'iddajuvxst', 'owner_id': 831, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'gzhyzmgzkb', 'owner_id': 832, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'yujzqmfzpm', 'owner_id': 833, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'bvwthxglhd', 'owner_id': 834, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'duzspjxnqj', 'owner_id': 835, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'pzwqcaragv', 'owner_id': 836, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'lbvbqaaqvh', 'owner_id': 837, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'yaqzryhouc', 'owner_id': 838, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'ilslevahly', 'owner_id': 839, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'ozeqlhauxr', 'owner_id': 840, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'afdngragah', 'owner_id': 841, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'mkjlpdnwst', 'owner_id': 842, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'colngaeqof', 'owner_id': 843, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'yyqrzfbvpx', 'owner_id': 844, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'ekvhkhmrrt', 'owner_id': 845, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'nkpvrhhhed', 'owner_id': 846, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'wyzsotzpuo', 'owner_id': 847, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'jrqecamuhm', 'owner_id': 848, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'sqbxerfznz', 'owner_id': 849, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'lcjjedcywz', 'owner_id': 850, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'coesqpbzzp', 'owner_id': 851, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'yldlakipsa', 'owner_id': 852, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'jsrmxbjify', 'owner_id': 853, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'tqnjbtqtnu', 'owner_id': 854, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'idjevcotoh', 'owner_id': 855, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'hwxkfecjri', 'owner_id': 856, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'yrrcwbozti', 'owner_id': 857, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'zoyicumpqa', 'owner_id': 858, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'ufgyrzxugx', 'owner_id': 859, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'bxghqpfyyk', 'owner_id': 860, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'tfahlmvjrb', 'owner_id': 861, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'crblnmlzns', 'owner_id': 862, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'kpdqmxykkl', 'owner_id': 863, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'tpidnfjugu', 'owner_id': 864, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'vzbioxajwn', 'owner_id': 865, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'nttdlkzcyf', 'owner_id': 866, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'bmtlmpfxds', 'owner_id': 867, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'ggjttmnwhz', 'owner_id': 868, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'mbgmntsnvb', 'owner_id': 869, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'sbwkhkdpkl', 'owner_id': 870, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'akccyqudkx', 'owner_id': 871, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'eqfihynmdj', 'owner_id': 872, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'plnfagaykr', 'owner_id': 873, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'dvokrpvycn', 'owner_id': 874, 'pets': {'cats': 0, 'dogs': 2}},
#  {'owner_name': 'dynftfbdzx', 'owner_id': 875, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'dyffrbeytt', 'owner_id': 876, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'bbyxidsgdc', 'owner_id': 877, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'adeqdexjvn', 'owner_id': 878, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'poxtmtklse', 'owner_id': 879, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'jtzmloczss', 'owner_id': 880, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'kdenmsakym', 'owner_id': 881, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'bcnplsmflg', 'owner_id': 882, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'ubxezakzfm', 'owner_id': 883, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'mwwwtxackv', 'owner_id': 884, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'ojreumplqm', 'owner_id': 885, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'rmdnxfvugw', 'owner_id': 886, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'ujdbyzwhpm', 'owner_id': 887, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'xwvmwxcwjn', 'owner_id': 888, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'jeizmnkimn', 'owner_id': 889, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'xdxkraodgq', 'owner_id': 890, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'mwaqfwbqcd', 'owner_id': 891, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'yqaqakqcca', 'owner_id': 892, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'mgksvtvcfa', 'owner_id': 893, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'tgisixolun', 'owner_id': 894, 'pets': {'cats': 4, 'dogs': 2}},
#  {'owner_name': 'sisvyzrgkp', 'owner_id': 895, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'cxbrxvymmn', 'owner_id': 896, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'kwaouzmlrf', 'owner_id': 897, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'tgxgliqwag', 'owner_id': 898, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'pzrmhlzbgj', 'owner_id': 899, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'bcrmedsvgq', 'owner_id': 900, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'tqznqqelpz', 'owner_id': 901, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'asukkmyhbe', 'owner_id': 902, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'kbtddbohaa', 'owner_id': 903, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'kvkgbhpybn', 'owner_id': 904, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'rctidnrsaq', 'owner_id': 905, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'kmbiwbqlkj', 'owner_id': 906, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ntzadhlqfa', 'owner_id': 907, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'qxogijgkoc', 'owner_id': 908, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'thmmciruzt', 'owner_id': 909, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'lgwmsehfip', 'owner_id': 910, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'uukxmbyiko', 'owner_id': 911, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'ggavdsofwt', 'owner_id': 912, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'hgwtljhskp', 'owner_id': 913, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'vgxlvocogg', 'owner_id': 914, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'kzjqtzovkr', 'owner_id': 915, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'wxdlterejg', 'owner_id': 916, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'ssuezvgppf', 'owner_id': 917, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'nobzgjfnlf', 'owner_id': 918, 'pets': {'cats': 2, 'dogs': 1}},
#  {'owner_name': 'bomntpsunt', 'owner_id': 919, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'ovalfoltdt', 'owner_id': 920, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'wsfvjqrdbk', 'owner_id': 921, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'fslhwhjgcp', 'owner_id': 922, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'pwzkbfrokl', 'owner_id': 923, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'stpjvtwngk', 'owner_id': 924, 'pets': {'cats': 4, 'dogs': 0}},
#  {'owner_name': 'lusxvbmtdx', 'owner_id': 925, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'iumgpwborp', 'owner_id': 926, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'prnqpsjswz', 'owner_id': 927, 'pets': {'cats': 1, 'dogs': 5}},
#  {'owner_name': 'hojqrjmskj', 'owner_id': 928, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'ownjmvfoms', 'owner_id': 929, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'ssixpfmcok', 'owner_id': 930, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'dcdlwkuwzt', 'owner_id': 931, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'ygoavzpxot', 'owner_id': 932, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'mhelziphrc', 'owner_id': 933, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'vjoqdmffwc', 'owner_id': 934, 'pets': {'cats': 0, 'dogs': 5}},
#  {'owner_name': 'nauplhcfxw', 'owner_id': 935, 'pets': {'cats': 4, 'dogs': 4}},
#  {'owner_name': 'hmenppgtop', 'owner_id': 936, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'whicqaniok', 'owner_id': 937, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'dibcgkzvzu', 'owner_id': 938, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'yyqrmdyqix', 'owner_id': 939, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'iqekflwqrp', 'owner_id': 940, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'ntiammykku', 'owner_id': 941, 'pets': {'cats': 5, 'dogs': 5}},
#  {'owner_name': 'spcolkazfv', 'owner_id': 942, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'rdmlgvdzfx', 'owner_id': 943, 'pets': {'cats': 2, 'dogs': 2}},
#  {'owner_name': 'aywfpqeoec', 'owner_id': 944, 'pets': {'cats': 0, 'dogs': 0}},
#  {'owner_name': 'tvjobsixqn', 'owner_id': 945, 'pets': {'cats': 2, 'dogs': 4}},
#  {'owner_name': 'ccntgwauwe', 'owner_id': 946, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'wsgtbarazl', 'owner_id': 947, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'lwgkibsbkh', 'owner_id': 948, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'yijwmrxycx', 'owner_id': 949, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'vaynrsxjhu', 'owner_id': 950, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'zhrccarhxs', 'owner_id': 951, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'nkgahpbhzf', 'owner_id': 952, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'zcjzlspoid', 'owner_id': 953, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'znkrvomkeh', 'owner_id': 954, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'bxlobeqezz', 'owner_id': 955, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'pamvzeuxlu', 'owner_id': 956, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'keodpfivqi', 'owner_id': 957, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'qkzptwdahg', 'owner_id': 958, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'rsqygexkwt', 'owner_id': 959, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'aujhvwtpgm', 'owner_id': 960, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'smpdxmxbqh', 'owner_id': 961, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'hordojtgdy', 'owner_id': 962, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'pznpcnavif', 'owner_id': 963, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'mpmyjxbokz', 'owner_id': 964, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'oagxyptrqo', 'owner_id': 965, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'mzzzggwuwh', 'owner_id': 966, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'yqiygarhpi', 'owner_id': 967, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'zhfnnolvml', 'owner_id': 968, 'pets': {'cats': 5, 'dogs': 4}},
#  {'owner_name': 'zxqlbnlfmb', 'owner_id': 969, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'qqtnwcbihn', 'owner_id': 970, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'dbwslgfmpp', 'owner_id': 971, 'pets': {'cats': 3, 'dogs': 5}},
#  {'owner_name': 'etowqdsxrj', 'owner_id': 972, 'pets': {'cats': 0, 'dogs': 3}},
#  {'owner_name': 'pczwytxmol', 'owner_id': 973, 'pets': {'cats': 5, 'dogs': 3}},
#  {'owner_name': 'qmqothcffz', 'owner_id': 974, 'pets': {'cats': 1, 'dogs': 0}},
#  {'owner_name': 'khlhkmoofk', 'owner_id': 975, 'pets': {'cats': 3, 'dogs': 2}},
#  {'owner_name': 'mcysqqtlke', 'owner_id': 976, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'wjqayrxznl', 'owner_id': 977, 'pets': {'cats': 4, 'dogs': 5}},
#  {'owner_name': 'gudttouhvp', 'owner_id': 978, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'cvscdsljpz', 'owner_id': 979, 'pets': {'cats': 1, 'dogs': 3}},
#  {'owner_name': 'femznalmer', 'owner_id': 980, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'zkyogmjrxu', 'owner_id': 981, 'pets': {'cats': 2, 'dogs': 0}},
#  {'owner_name': 'ypcigfxdat', 'owner_id': 982, 'pets': {'cats': 4, 'dogs': 3}},
#  {'owner_name': 'beilpujnuy', 'owner_id': 983, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'zoekyqbqxy', 'owner_id': 984, 'pets': {'cats': 1, 'dogs': 2}},
#  {'owner_name': 'uyzcrqxtlx', 'owner_id': 985, 'pets': {'cats': 5, 'dogs': 0}},
#  {'owner_name': 'ujmqkkdzxy', 'owner_id': 986, 'pets': {'cats': 3, 'dogs': 4}},
#  {'owner_name': 'pglwcmcggh', 'owner_id': 987, 'pets': {'cats': 0, 'dogs': 1}},
#  {'owner_name': 'kkbisoxpmf', 'owner_id': 988, 'pets': {'cats': 0, 'dogs': 4}},
#  {'owner_name': 'rqeqwaowfb', 'owner_id': 989, 'pets': {'cats': 2, 'dogs': 3}},
#  {'owner_name': 'exhgeoqzso', 'owner_id': 990, 'pets': {'cats': 3, 'dogs': 1}},
#  {'owner_name': 'xbdxkgkast', 'owner_id': 991, 'pets': {'cats': 2, 'dogs': 5}},
#  {'owner_name': 'siqbubpshw', 'owner_id': 992, 'pets': {'cats': 4, 'dogs': 1}},
#  {'owner_name': 'opcgzppqoo', 'owner_id': 993, 'pets': {'cats': 3, 'dogs': 0}},
#  {'owner_name': 'hdidunqmtm', 'owner_id': 994, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'csvjaherha', 'owner_id': 995, 'pets': {'cats': 3, 'dogs': 3}},
#  {'owner_name': 'bzglbbgxzp', 'owner_id': 996, 'pets': {'cats': 5, 'dogs': 2}},
#  {'owner_name': 'hznwafcjji', 'owner_id': 997, 'pets': {'cats': 5, 'dogs': 1}},
#  {'owner_name': 'ibypfsxwoz', 'owner_id': 998, 'pets': {'cats': 1, 'dogs': 4}},
#  {'owner_name': 'kiztyvyuam', 'owner_id': 999, 'pets': {'cats': 2, 'dogs': 5}}]

# %%
upload_res = es_mgr.create_document(collection_name = "meow", documents=rand_data, id_field='owner_name')
# Out:
# List of faulty documents: []
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
upload_res
# Out:
# {'response': '200',
#  'ids': ['lnrhlqcncv',
#   'clkwivkdhw',
#   'gstnqvfwtp',
#   'vkoodqrllo',
#   'vrowmvilat',
#   'yuxkhbetfh',
#   'ocmvaylszk',
#   'usnkgkzjyt',
#   'vpebtbldvw',
#   'asjxnxdoqn',
#   'hontqlnwoo',
#   'txmqlfkdke',
#   'qiaflgwrqr',
#   'doxtystqry',
#   'aubrezdwhk',
#   'rjavtsciam',
#   'grixpvzhmj',
#   'gmamwrpxuj',
#   'nfprhshykn',
#   'nsqpyievxs',
#   'oekpkuejbc',
#   'vnljigkuij',
#   'ylazhhnxee',
#   'blppqhutbl',
#   'fqdtrlimjl',
#   'fqkbtyzydj',
#   'qpyxpklavp',
#   'myoslmgokh',
#   'pigxupacue',
#   'wagrfowora',
#   'tlzvopqxxy',
#   'olzlgvkokh',
#   'kxfeeehjds',
#   'ybqgwlxjgo',
#   'ivkbmsddel',
#   'ljxgzhgfnb',
#   'pohvjerfpt',
#   'uzmlgshecx',
#   'spntypcgwn',
#   'nypljtytum',
#   'libjncsdul',
#   'ryzljmlmbk',
#   'nrwwgmqrms',
#   'docarprobg',
#   'uytngdqfis',
#   'wcgzuafwxl',
#   'ykbriycorx',
#   'wjbjnqjxho',
#   'zvzupffxzc',
#   'mvkhoncwjp',
#   'gkuzbktjci',
#   'rnaewdrqdm',
#   'oejtmseksm',
#   'ydfxouhasj',
#   'jthgsmmmgn',
#   'ohbqdlrqhi',
#   'jivrppmnaq',
#   'zycfisacxr',
#   'dvsqltxgxt',
#   'uozjkdgyal',
#   'spmascbazv',
#   'kxuxexqzqn',
#   'krqwojuzam',
#   'iamkjeszcp',
#   'exgfowibix',
#   'ayjujqfcls',
#   'xovtzinwgu',
#   'xzmxlypcet',
#   'iecyapecon',
#   'uhmjxroxyv',
#   'tztbsbehra',
#   'prezjkplpe',
#   'btxvoxvnmz',
#   'irkixhipro',
#   'ixxnrgjwuc',
#   'jdaidzyuur',
#   'lashjffqpv',
#   'uehfvwrusc',
#   'fcgtrxayru',
#   'wxnvbkbmqf',
#   'nssetramgj',
#   'cusdeyybcy',
#   'tabtndchyx',
#   'zwhddcrlzk',
#   'xzygjyfizt',
#   'ttyzfkxkhr',
#   'ayhknvumnh',
#   'qicrxpptmp',
#   'fsscxtvzcu',
#   'kbqidscuib',
#   'nuuiysgbpq',
#   'vwzkjgmbyo',
#   'exjmqlvgeb',
#   'xrmxtdjoce',
#   'qroiymannk',
#   'owoeofkdxh',
#   'hqvgvewknp',
#   'zkmqezlygv',
#   'rgkxglgmom',
#   'lozdnhaulw',
#   'ydebcpcyne',
#   'rpdtmqoskp',
#   'dexwziaatd',
#   'wlvzafovyn',
#   'zsxjtovske',
#   'eigiunrppq',
#   'klfraocula',
#   'bthqnmsdgr',
#   'jvsfwlhkyh',
#   'bkeqgtuqwu',
#   'rvxsdyxgxg',
#   'osudyvcecn',
#   'pvttlsruib',
#   'gpectgsesa',
#   'tubtytufgu',
#   'duiqigsfou',
#   'txrpholvva',
#   'wfkqlfrahy',
#   'lsmktjlyku',
#   'geqxnjmgeg',
#   'ocrgeingqg',
#   'zmsycsvykp',
#   'kebzfnpiwe',
#   'jbwkdxaapp',
#   'ldlwilguan',
#   'cjwrmjiupo',
#   'zuvcstqhnf',
#   'rofkoeeilq',
#   'dvsegntkow',
#   'kyjowyqbbp',
#   'fzlowitrox',
#   'evpvuqodpa',
#   'miyzwzunwr',
#   'qykmonpcur',
#   'sgrvgrphot',
#   'hhrnjqpvnv',
#   'uyvdxinsxm',
#   'obpmjtgxdb',
#   'tvlrozgiqk',
#   'czsdnndagc',
#   'hbuboepcmp',
#   'xvybtmsyra',
#   'lyelvbibln',
#   'uqtxlyralc',
#   'whgsgadsal',
#   'vhlrmdoyqg',
#   'acmgcfifim',
#   'xfdblsagpf',
#   'rxalavkdpd',
#   'gnvimzbytp',
#   'vlqusrqafu',
#   'luvrzoawfu',
#   'rzzhgeldsu',
#   'rfykesafjw',
#   'gkriyajyws',
#   'aybtquwyzf',
#   'rjtbpzuqku',
#   'ygijctxple',
#   'djbcbxillk',
#   'rinmxdkbkd',
#   'sthuqsthav',
#   'tjcvjgvvjw',
#   'atbpjpmbkq',
#   'ncbvgfmejq',
#   'petxvzcjga',
#   'ycgbwerisr',
#   'bhjyvupqiv',
#   'fsqxxfggwl',
#   'cmihublvtd',
#   'mmsaorlmnq',
#   'cpmpkkyhkz',
#   'jgjmrnamdd',
#   'jxcjcogtbl',
#   'xgnhqeyaaf',
#   'mygiggpvky',
#   'ywyyzopaxx',
#   'csdrbzjpln',
#   'aealszmhwj',
#   'dugxbwtmmc',
#   'uqunmimxfp',
#   'rrjgoketom',
#   'hbreuuljuy',
#   'wyyhoikyjt',
#   'bynylkyrcb',
#   'kwyonvipwr',
#   'zghyyiismz',
#   'vrkmrvshyd',
#   'zldtdflisn',
#   'rtlfnurkbe',
#   'ahgmadhqps',
#   'qwkplxeelv',
#   'qinqzipytq',
#   'qcpxxwheno',
#   'mmiijqzfjy',
#   'hjnerlgvtv',
#   'cbyjrwtrwd',
#   'ziuzawvzgu',
#   'lmbtwbslwe',
#   'ydsefwibga',
#   'qtcsrxqbfs',
#   'zvtxdkqort',
#   'mfwkormece',
#   'fbevhwcitl',
#   'plpjlnfvvv',
#   'avuyklrazx',
#   'uwanflwddg',
#   'kethihkwbl',
#   'fpieilunub',
#   'nycanspzru',
#   'jafphfrarn',
#   'ptqglqjfyp',
#   'gnvdhlquyt',
#   'omgxyeqmnl',
#   'vmpyasybmj',
#   'ljdkziilzf',
#   'etjxyhzmod',
#   'crffijvnfe',
#   'kmrzlofvcu',
#   'sddondjmvg',
#   'yojdpswlor',
#   'ajgynssjes',
#   'patydjszoo',
#   'gxbhpozbgk',
#   'czrxfxdkgx',
#   'wvxhimobxl',
#   'jygkrypmqb',
#   'ainkenrjay',
#   'hrvcejlhja',
#   'vwvvqkdxus',
#   'txdwfpfmya',
#   'bgepqlsbja',
#   'iglaqihwkv',
#   'ymenrikdjh',
#   'kojdglrcoj',
#   'abnpfrejex',
#   'hvtrgibkxi',
#   'ciatcjwzmk',
#   'xctwrdbols',
#   'xqmofadrbd',
#   'tgkukkmtzm',
#   'fdbbydztri',
#   'xtghsuomka',
#   'pdncpqcgio',
#   'bhxfvzhlue',
#   'smvaihoiux',
#   'ltcmadhfqp',
#   'erufkmdqcj',
#   'riuyvgvlcb',
#   'aoqbhjubms',
#   'nzonvhmbge',
#   'jutvoebcws',
#   'chumgqmrgy',
#   'vxyomiscae',
#   'uqttbohtcb',
#   'ewzqqrhkmz',
#   'lfdlfjhcsv',
#   'ethiszzmmc',
#   'yyczaimkjd',
#   'rirvleavdz',
#   'adnsxxvrmi',
#   'usaidfywyz',
#   'ptmaevxnyx',
#   'wwexdenpdr',
#   'ulaedpdfvx',
#   'rsgphsqtzn',
#   'jgalxevnbu',
#   'slwttktxyv',
#   'eoegkrtvkg',
#   'pxuusbvmil',
#   'gzkxzcjbqm',
#   'iywnktxoqs',
#   'vbblhxzudr',
#   'ahojdpszkh',
#   'kpmsgllnjd',
#   'smdbksjgmk',
#   'ydidxvjfwn',
#   'chmzeeghqu',
#   'wzyxyohpao',
#   'ivmcyyyqma',
#   'chnxxohmpc',
#   'imtxastojj',
#   'fwjsgwclgd',
#   'dsyjnnmdww',
#   'oxhkbawyso',
#   'xbtpmwnocz',
#   'wsyhhxnpco',
#   'ipwxijvcsg',
#   'vqyaliqubo',
#   'gczssajjab',
#   'joewkosdxo',
#   'bttcprweoj',
#   'vexznxeznm',
#   'uzmzihotpy',
#   'uxfhhxnbcj',
#   'tdtcxsytmw',
#   'nzhrjmrrrh',
#   'zvthpkethd',
#   'kkszkuezjp',
#   'skdyhgtlny',
#   'qgrvgdxfty',
#   'agvrzhjsbh',
#   'hsxxaairfd',
#   'lvlbvgxsds',
#   'deeuammjdi',
#   'ptljkpekmu',
#   'codsdmrsql',
#   'ynrmojevfr',
#   'palnnwmntc',
#   'mfjteifxiu',
#   'yicbuzfand',
#   'rjkfxusdth',
#   'kwkeyrcxmo',
#   'ovbloqentn',
#   'wtiklzbwbi',
#   'czfobxtbkp',
#   'owlatbfiyx',
#   'xbqurcbswi',
#   'zbpalyijjt',
#   'omcwtedxth',
#   'chqgwsqtux',
#   'pqkksguerq',
#   'swhwoeukqf',
#   'yzmannihbm',
#   'fcjoblubzk',
#   'hpdzzcxhzn',
#   'dizjqedkce',
#   'ckqqdxbqab',
#   'ljvvykyugk',
#   'gpqlgwmvqf',
#   'gufhxzdunm',
#   'nswwtskaoy',
#   'dpxxejpvkr',
#   'kzipkqtejg',
#   'sakphhxkui',
#   'dzzbeobftm',
#   'teujbmhpzm',
#   'iawlhucdou',
#   'eagtlviokc',
#   'qcufbedtmp',
#   'lwwmyadzdt',
#   'vhtkpqnbvh',
#   'fylmhqdiad',
#   'uqrvdnvxcg',
#   'ksiuqrtcpm',
#   'sdjkkrjwxr',
#   'zpdumxcmiv',
#   'gmapnttynf',
#   'mhnruixehq',
#   'gwecdaputd',
#   'kugyyqoyeo',
#   'manbcwhymt',
#   'rpjbsqxyfp',
#   'kwlgwltsht',
#   'adkzpbooqv',
#   'irjsltpeqs',
#   'sqardepxfz',
#   'mqqfteuhyb',
#   'hxguqqjwgn',
#   'dgqwvngckq',
#   'rurgqzgeyq',
#   'xocxpraiwj',
#   'tvfnqxjrkk',
#   'shmzfavzzv',
#   'esamkghgjk',
#   'pzmapjxzaw',
#   'xskpfwavdf',
#   'bgwkjpgvdm',
#   'lmpecfjgsd',
#   'bpbcsdyzem',
#   'trcyanzmhg',
#   'itqznjozss',
#   'nstmzossfe',
#   'aeupigcptm',
#   'gdqtjuacbh',
#   'wnbdrausod',
#   'xmrsvosfmr',
#   'eptbmebvim',
#   'xxlbtzfxlk',
#   'aiomlcryit',
#   'afqioudjpj',
#   'avfohqkklg',
#   'vlpklgevgi',
#   'perubpyiid',
#   'rwlorxgpdh',
#   'evwlwospzh',
#   'oeibtnuiyj',
#   'gllvekhomq',
#   'pdlfetyjlx',
#   'hyoamhhvtb',
#   'ewrxbzyzhk',
#   'hxzyocmekg',
#   'lcozewopvh',
#   'iodjquwbuv',
#   'lxgqgtcngq',
#   'iquxnvfwxc',
#   'lijtddmhoi',
#   'vzwahtnbqm',
#   'skeclrnapq',
#   'qfgmuqmjsf',
#   'qsccxckdke',
#   'syynrwzkkt',
#   'oictbaeouy',
#   'qfkkbngngc',
#   'asyrwyfcdd',
#   'qgtspajqkk',
#   'kcapivfmkh',
#   'dnfndqpynh',
#   'nobpxddlov',
#   'nzpefmsikl',
#   'gltsjvbmbb',
#   'ykfelbrzzu',
#   'pvwkwpubfq',
#   'qlakkioxix',
#   'oaahcstzth',
#   'gxqacmikpk',
#   'myedifxpys',
#   'iehajodirm',
#   'tszqjtlxrv',
#   'hgmjmbwjjw',
#   'yjsdlrliiy',
#   'jgnqfrxztj',
#   'thfrbsoojg',
#   'jhdgdlflof',
#   'acizlkcbow',
#   'qrorankhnb',
#   'dquthciuhu',
#   'wguycmswbg',
#   'hrcjaagpay',
#   'kdywljngsr',
#   'japcxvfxbx',
#   'wrpksxjlwa',
#   'pkcehttrxb',
#   'wrjwcatzfw',
#   'netlolutsf',
#   'uefuicoeec',
#   'rcamyivgvi',
#   'jmduesfkjt',
#   'fknvjnlswh',
#   'wqyebxqykh',
#   'jbqdqubjyi',
#   'pouirryjem',
#   'eowrunalou',
#   'nwpwpcubmp',
#   'swzxsdfaag',
#   'wxlnmoycee',
#   'dluiytnqoi',
#   'qvsbwlfzum',
#   'fpvmdwdjhj',
#   'ddgekkxdoh',
#   'echxtyjpnd',
#   'efxlxemqkc',
#   'bgsgpfblym',
#   'bjgrdvbgdw',
#   'hjtseyirsk',
#   'vtuozzntom',
#   'gfprkzqdcw',
#   'jdwgkrbtqe',
#   'ajoxuzfbzb',
#   'kwjipkkgvs',
#   'znpqvhfstf',
#   'cjbulaxlei',
#   'ozkuxzhkve',
#   'zkvdmhnacp',
#   'zstjzlbdsb',
#   'qkxgoeebyi',
#   'zexfkkavzm',
#   'endottvueu',
#   'kxyaolwofc',
#   'ndiomfskol',
#   'gwphhtklbt',
#   'mtlfjjoosf',
#   'qhwlbkjckj',
#   'idbgdfjqts',
#   'iirsdmsvmx',
#   'nkzrvupnag',
#   'ecascazpho',
#   'kavdwwnuph',
#   'wcijycswuo',
#   'krqzkrsxxx',
#   'vglfhrvmyd',
#   'hqvcevzkzo',
#   'ueyxxshjbs',
#   'oahcrjkuuh',
#   'frhjpcmmbp',
#   'wexmiafivf',
#   'zamgrfhbln',
#   'wbozefjgkc',
#   'yugagcqgvf',
#   'bfaepjxiqr',
#   'pioezevtko',
#   'rqoklouyzn',
#   'aneightvme',
#   'bmezecicvv',
#   'vtnvhueobl',
#   'xuecztpebc',
#   'bfzlzrwepl',
#   'pxebhbqqap',
#   'zxmkjpshsb',
#   'yvzuvkvfaq',
#   'qkfrvksfdq',
#   'fduoplbwqh',
#   'ivnmnugtxq',
#   'markyvjpue',
#   'ecgdvauoch',
#   'rmaeihcohw',
#   'dzhlmmdgwv',
#   'mgmwlpuftu',
#   'pccvvtwpxs',
#   'izbjgqxesi',
#   'cafzglbflx',
#   'txertcfjru',
#   'vburtjnkfv',
#   'xuqshamxee',
#   'wznzmntsig',
#   'hwdmhbncgh',
#   'hsvzlhajrt',
#   'yjghfvjvbh',
#   'nnekzdplig',
#   'cnaruievgk',
#   'edvpvusaua',
#   'famfdfzsow',
#   'rwifwbgjmd',
#   'bmwmhlztim',
#   'djkmbjkcxn',
#   'ippbaxrxwh',
#   'jseatygfep',
#   'whzgfuipju',
#   'ydttlteyst',
#   'fhxrsiafif',
#   'eshercglfx',
#   'icuikrwqqr',
#   'xzhbeqeoqb',
#   'czsozpczdf',
#   'rhqyxfeeht',
#   'hqapxoapgc',
#   'bxrswefrmo',
#   'pkvaumkqoi',
#   'dqwbsrcxab',
#   'ukksiiiftd',
#   'mlvrovgvxm',
#   'pkucuffogh',
#   'oolukswzdl',
#   'fyjmkxyiuk',
#   'auxxpfiqqo',
#   'hkwhakztwf',
#   'juwpeoedkj',
#   'hmfikppdha',
#   'gdnxjufeih',
#   'padwufpsfh',
#   'xakiacwlmg',
#   'wrgnyjwplv',
#   'qdtjbaojlk',
#   'ktrefzpxbo',
#   'rklymoiugb',
#   'nlbzoivrws',
#   'wtzwzeiyjm',
#   'fxgelnjspf',
#   'bxhamdnwdv',
#   'snsdgydkim',
#   'oaskrwcrye',
#   'lhppvboehg',
#   'kssgiqignz',
#   'kwhdyvqybx',
#   'zvjasuwczl',
#   'kfsjmjetdt',
#   'gqewpfvlpn',
#   'bwhnxnjenh',
#   'mtavosawvf',
#   'rvoltiylte',
#   'zyemnefzvd',
#   'vgtryoxnkz',
#   'iqbewnjecw',
#   'yewglvdogw',
#   'riwrifheby',
#   'gwculavbqv',
#   'nxgwpevjrq',
#   'tukmjhrigt',
#   'ljlacxzlas',
#   'pvslqmhnrt',
#   'xfmjruymxl',
#   'csmddbwyco',
#   'roivmrqhxn',
#   'matfhoevkn',
#   'needoqiayc',
#   'riolxdvnru',
#   'niifrtejkm',
#   'ppttaekffo',
#   'qvtgsfvwdb',
#   'rvukjotwgm',
#   'ewezyggiee',
#   'szfcbslvkc',
#   'yqmrskzfbt',
#   'owukbcnjls',
#   'kltczdcunu',
#   'mpelxncqad',
#   'ockxhzftdd',
#   'rjngfdtder',
#   'ifygebyfzj',
#   'cbkvcikmwd',
#   'rmxxjadnwu',
#   'kmfkvtraug',
#   'kllwbextiq',
#   'gaxslxpghp',
#   'ewwegbihou',
#   'wlvzqfrbyd',
#   'klevfwjrmo',
#   'efdmxqwmla',
#   'shqlcyhpoj',
#   'nhiexxwpsd',
#   'kofqszgydx',
#   'aawyqackwn',
#   'atzuuycldv',
#   'uualiydsau',
#   'kdyxbneldz',
#   'xiqoorwrbq',
#   'iaushhtfkh',
#   'aunbmynnhu',
#   'hzynhmlnhm',
#   'ehkzfogkoh',
#   'yxvbxqlhba',
#   'vdwdbicrsk',
#   'eycoervuhl',
#   'rebinaqxgj',
#   'fduhqvvucp',
#   'ckhhmuibpx',
#   'avyhdgbidq',
#   'thkztjixlj',
#   'iclvmikint',
#   'vzsuqcnvbb',
#   'ponrkkrwop',
#   'iofwiiamkk',
#   'fsykrdoaij',
#   'lmwlkbtmdy',
#   'snlickdtmf',
#   'gmsohbncak',
#   'oeuhrzkrrz',
#   'vtblxlxdfm',
#   'jrjzshnian',
#   'tncjjywvpm',
#   'rxxmpyjicf',
#   'ltpflaxxbq',
#   'qjyqrziroo',
#   'uomqabbbzo',
#   'nepznqdkbw',
#   'zltwmtwjqn',
#   'uvfkqxbhxq',
#   'jnlbcrgtqo',
#   'oxdydasijz',
#   'kpsezzqbvk',
#   'jzqurzehin',
#   'tzcrlajxca',
#   'xmjsmgqjob',
#   'qwhgiibkwm',
#   'sejzuwiwcp',
#   'rejenceedf',
#   'zvydxzycor',
#   'yrcpmtblvm',
#   'csdmlsgjmv',
#   'yrjcbwmqta',
#   'koijxfhxqv',
#   'pifkiojvbo',
#   'hsiuzjofjm',
#   'fnzomzqpbx',
#   'raqzekrggu',
#   'icsiaborcf',
#   'lhretkxqwi',
#   'zfwzutkqvr',
#   'uqonkvlfvz',
#   'nrllnrrcra',
#   'scgvphbywl',
#   'atuejoowbw',
#   'fjgzmlmchr',
#   'ddbdqffkin',
#   'iueemduxis',
#   'vqwfdkwthh',
#   'tgmnkupybh',
#   'kybiopbojf',
#   'sytlodidzf',
#   'rbzyphixjz',
#   'cvhiugpvsh',
#   'edcirxgtci',
#   'lwkdbwxqnh',
#   'xdmwmbgdds',
#   'wouzspckld',
#   'pqktiohcts',
#   'hczzybzwfy',
#   'nljazzwqps',
#   'amiaumfytv',
#   'ypdruqcpkz',
#   'rbjfprzsir',
#   'aeeqpbilnn',
#   'sxtnvgvzhl',
#   'kmpejhvtew',
#   'tossymszcm',
#   'wvyunfwuwp',
#   'bequzwldhf',
#   'kfzapxyhko',
#   'bbittdorsj',
#   'cyswqpsnuc',
#   'usjhcbgwzm',
#   'xwdhueeaoz',
#   'dpqhmxymjl',
#   'fknfsqwefc',
#   'layxpfvfsm',
#   'afljexuzwz',
#   'ebaywueanq',
#   'dvtrgzpdhl',
#   'qpttzrwmcv',
#   'nskdbavfse',
#   'egudzbctqo',
#   'hfsstnrqkk',
#   'awqsqoufnp',
#   'ybgnlkihvz',
#   'uwsyrluafe',
#   'vzmscmqcff',
#   'yjiwuundpe',
#   'bhtxcgchzb',
#   'qadbzmrlgk',
#   'rqnjacsagy',
#   'tdwenfvyni',
#   'odfjtjhwdd',
#   'jfhhnwgtxm',
#   'zmrheybpus',
#   'cbziogaccm',
#   'fdyygxknvh',
#   'huheotjzri',
#   'vhptrawmrn',
#   'wkbpitsfvu',
#   'qlkuddmkcd',
#   'kwfwccqfrv',
#   'dqaybyukbp',
#   'hpzjkhudou',
#   'wrhmndotdg',
#   'zssxpgeekr',
#   'ukxziljcsb',
#   'ruhhxulugs',
#   'fcfddvqpga',
#   'iktqdyexjn',
#   'sarzpxabxm',
#   'scclvmfyak',
#   'azohxaaxwv',
#   'hqrrwuncch',
#   'jtgomlrzob',
#   'yzzovblkcd',
#   'mksrbpiuaw',
#   'myvitebgqk',
#   'dzhizhkchq',
#   'lushvhcveb',
#   'fqdviwovcl',
#   'jgfsvgfttr',
#   'scavfwvupd',
#   'srcluryrnh',
#   'rwuexlmosp',
#   'waouldxald',
#   'sbwpnlfkqm',
#   'qwnljkjonj',
#   'fwbzxqxzdo',
#   'vbpbhiydzh',
#   'vobddhidgv',
#   'ghxbidjrhh',
#   'jvkhgyimuj',
#   'sxdkebhsgz',
#   'ouujfkrewh',
#   'otpvnhyuoj',
#   'yfkvnwvxsn',
#   'usbjhvtkpj',
#   'vomwhewwgj',
#   'nctzypgamt',
#   'bbmpmwvgey',
#   'xnyezyfryj',
#   'xzevnuczgj',
#   'cwriybsotn',
#   'hujdxlauou',
#   'qmarzvhvft',
#   'hlwduunnac',
#   'djejxqzhwl',
#   'mnlmfxqgio',
#   'plpvsvagfy',
#   'omszoeorxt',
#   'vesiwwchoq',
#   'awydjfupbj',
#   'ztlcfssimz',
#   'rexwtjrpjg',
#   'pkxkmetjbo',
#   'tvqnrchtzp',
#   'ewjdlczquy',
#   'lwohgftqzx',
#   'qmoqqelugh',
#   'ajrutsctzl',
#   'kllweiylqo',
#   'rqiumfbzks',
#   'wiuapjagmy',
#   'ibqqihcebq',
#   'wrftdkzsbi',
#   'hdrxeobzsu',
#   'fbhfqwjtvf',
#   'oilbboazkv',
#   'evjnukunbq',
#   'yzltfemasn',
#   'adzwzqbfys',
#   'vbacbtmors',
#   'pbmhvnbcbl',
#   'rthsnoqadi',
#   'ercppxedxy',
#   'nuovnjqpbx',
#   'gpohxwnyad',
#   'plnltyhdkg',
#   'bgxtspfhpx',
#   'vqxioiynql',
#   'fkbpkiylgy',
#   'baazegxeox',
#   'pplfbpyxxq',
#   'gltlpetjrb',
#   'akyzakqzfp',
#   'hqlzfirgws',
#   'mvxrpcnaun',
#   'macjfpkdth',
#   'kgtnfbgfze',
#   'zaxbjdayat',
#   'tlsldqdsyv',
#   'vnwkidtgvb',
#   'yrknjmctsm',
#   'zptzhxviik',
#   'qraiasooit',
#   'dldyykmjze',
#   'mvpigpsfnf',
#   'ttxhkwzwzw',
#   'tbxdjdynhy',
#   'askstgfycj',
#   'nsroovltjk',
#   'juiyqrqmdu',
#   'iddajuvxst',
#   'gzhyzmgzkb',
#   'yujzqmfzpm',
#   'bvwthxglhd',
#   'duzspjxnqj',
#   'pzwqcaragv',
#   'lbvbqaaqvh',
#   'yaqzryhouc',
#   'ilslevahly',
#   'ozeqlhauxr',
#   'afdngragah',
#   'mkjlpdnwst',
#   'colngaeqof',
#   'yyqrzfbvpx',
#   'ekvhkhmrrt',
#   'nkpvrhhhed',
#   'wyzsotzpuo',
#   'jrqecamuhm',
#   'sqbxerfznz',
#   'lcjjedcywz',
#   'coesqpbzzp',
#   'yldlakipsa',
#   'jsrmxbjify',
#   'tqnjbtqtnu',
#   'idjevcotoh',
#   'hwxkfecjri',
#   'yrrcwbozti',
#   'zoyicumpqa',
#   'ufgyrzxugx',
#   'bxghqpfyyk',
#   'tfahlmvjrb',
#   'crblnmlzns',
#   'kpdqmxykkl',
#   'tpidnfjugu',
#   'vzbioxajwn',
#   'nttdlkzcyf',
#   'bmtlmpfxds',
#   'ggjttmnwhz',
#   'mbgmntsnvb',
#   'sbwkhkdpkl',
#   'akccyqudkx',
#   'eqfihynmdj',
#   'plnfagaykr',
#   'dvokrpvycn',
#   'dynftfbdzx',
#   'dyffrbeytt',
#   'bbyxidsgdc',
#   'adeqdexjvn',
#   'poxtmtklse',
#   'jtzmloczss',
#   'kdenmsakym',
#   'bcnplsmflg',
#   'ubxezakzfm',
#   'mwwwtxackv',
#   'ojreumplqm',
#   'rmdnxfvugw',
#   'ujdbyzwhpm',
#   'xwvmwxcwjn',
#   'jeizmnkimn',
#   'xdxkraodgq',
#   'mwaqfwbqcd',
#   'yqaqakqcca',
#   'mgksvtvcfa',
#   'tgisixolun',
#   'sisvyzrgkp',
#   'cxbrxvymmn',
#   'kwaouzmlrf',
#   'tgxgliqwag',
#   'pzrmhlzbgj',
#   'bcrmedsvgq',
#   'tqznqqelpz',
#   'asukkmyhbe',
#   'kbtddbohaa',
#   'kvkgbhpybn',
#   'rctidnrsaq',
#   'kmbiwbqlkj',
#   'ntzadhlqfa',
#   'qxogijgkoc',
#   'thmmciruzt',
#   'lgwmsehfip',
#   'uukxmbyiko',
#   'ggavdsofwt',
#   'hgwtljhskp',
#   'vgxlvocogg',
#   'kzjqtzovkr',
#   'wxdlterejg',
#   'ssuezvgppf',
#   'nobzgjfnlf',
#   'bomntpsunt',
#   'ovalfoltdt',
#   'wsfvjqrdbk',
#   'fslhwhjgcp',
#   'pwzkbfrokl',
#   'stpjvtwngk',
#   'lusxvbmtdx',
#   'iumgpwborp',
#   'prnqpsjswz',
#   'hojqrjmskj',
#   'ownjmvfoms',
#   'ssixpfmcok',
#   'dcdlwkuwzt',
#   'ygoavzpxot',
#   'mhelziphrc',
#   'vjoqdmffwc',
#   'nauplhcfxw',
#   'hmenppgtop',
#   'whicqaniok',
#   'dibcgkzvzu',
#   'yyqrmdyqix',
#   'iqekflwqrp',
#   'ntiammykku',
#   'spcolkazfv',
#   'rdmlgvdzfx',
#   'aywfpqeoec',
#   'tvjobsixqn',
#   'ccntgwauwe',
#   'wsgtbarazl',
#   'lwgkibsbkh',
#   'yijwmrxycx',
#   'vaynrsxjhu',
#   'zhrccarhxs',
#   'nkgahpbhzf',
#   'zcjzlspoid',
#   'znkrvomkeh',
#   'bxlobeqezz',
#   'pamvzeuxlu',
#   'keodpfivqi',
#   'qkzptwdahg',
#   'rsqygexkwt',
#   'aujhvwtpgm',
#   'smpdxmxbqh',
#   'hordojtgdy',
#   'pznpcnavif',
#   'mpmyjxbokz',
#   'oagxyptrqo',
#   'mzzzggwuwh',
#   'yqiygarhpi',
#   'zhfnnolvml',
#   'zxqlbnlfmb',
#   'qqtnwcbihn',
#   'dbwslgfmpp',
#   'etowqdsxrj',
#   'pczwytxmol',
#   'qmqothcffz',
#   'khlhkmoofk',
#   'mcysqqtlke',
#   'wjqayrxznl',
#   'gudttouhvp',
#   'cvscdsljpz',
#   'femznalmer',
#   'zkyogmjrxu',
#   'ypcigfxdat',
#   'beilpujnuy',
#   'zoekyqbqxy',
#   'uyzcrqxtlx',
#   'ujmqkkdzxy',
#   'pglwcmcggh',
#   'kkbisoxpmf',
#   'rqeqwaowfb',
#   'exhgeoqzso',
#   'xbdxkgkast',
#   'siqbubpshw',
#   'opcgzppqoo',
#   'hdidunqmtm',
#   'csvjaherha',
#   'bzglbbgxzp',
#   'hznwafcjji',
#   'ibypfsxwoz',
#   'kiztyvyuam']}

# %%
delete_res = es_mgr.delete_document(collection_name = "meow", doc_id='Yzy8E4UBimE7927zEki1')
# Out:
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
delete_res
# Out:
# {'response': '200',
#  'api_resp': ObjectApiResponse({'_index': 'meow', '_id': 'Yzy8E4UBimE7927zEki1', '_version': 2, 'result': 'deleted', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1002, '_primary_term': 1})}

# %%
some_text = "meow"
_check_data_type(some_text, int)
# Out:
# False

# %%
es_mgr.client.update(index="meow", id='kxfeeehjds', doc={'pets':{'cats':4}})
# Out:
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ObjectApiResponse({'_index': 'meow', '_id': 'kxfeeehjds', '_version': 2, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1000, '_primary_term': 1})

# %%
search_res['hits']['hits'][0]['_source']
# Out:
# {'owner_id': 32, 'pets': {'cats': 4, 'dogs': 1}}

# %%
es_mgr.read_document(collection_name='meow', doc_id='kxfeeehjds')
# Out:
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'response': '200',
#  'api_resp': [{'_index': 'meow',
#    '_id': 'kxfeeehjds',
#    '_score': 1.0,
#    '_source': {'owner_id': 32, 'pets': {'cats': 4, 'dogs': 1}}}]}

# %%
es_mgr.query_collection(collection_name='meow', field_value_dict={'owner_id':3})
# Out:
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'response': '200',
#  'api_resp': [{'_index': 'meow',
#    '_id': 'vkoodqrllo',
#    '_score': 6.5042877,
#    '_source': {'owner_id': 3, 'pets': {'cats': 0, 'dogs': 0}}}]}

# %%
import collections

def flatten(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
flatten({'pets':{'cats':4}})
# Out:
# /tmp/ipykernel_25/1142123797.py:7: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   if isinstance(v, collections.MutableMapping):
# {'pets.cats': 4}

# %%
docs_response = scan(es_mgr.client, index='meow', query={"query":{"match":{'pets.cats':3}}})

# %%
for i in docs_response:
    print(i)
# Out:
# {'_index': 'meow', '_id': 'clkwivkdhw', '_score': None, '_source': {'owner_id': 1, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [1]}
# {'_index': 'meow', '_id': 'vrowmvilat', '_score': None, '_source': {'owner_id': 4, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [4]}
# {'_index': 'meow', '_id': 'yuxkhbetfh', '_score': None, '_source': {'owner_id': 5, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [5]}
# {'_index': 'meow', '_id': 'ocmvaylszk', '_score': None, '_source': {'owner_id': 6, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [6]}
# {'_index': 'meow', '_id': 'txmqlfkdke', '_score': None, '_source': {'owner_id': 11, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [11]}
# {'_index': 'meow', '_id': 'ylazhhnxee', '_score': None, '_source': {'owner_id': 22, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [22]}
# {'_index': 'meow', '_id': 'ybqgwlxjgo', '_score': None, '_source': {'owner_id': 33, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [33]}
# {'_index': 'meow', '_id': 'dvsqltxgxt', '_score': None, '_source': {'owner_id': 58, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [58]}
# {'_index': 'meow', '_id': 'iamkjeszcp', '_score': None, '_source': {'owner_id': 63, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [63]}
# {'_index': 'meow', '_id': 'tztbsbehra', '_score': None, '_source': {'owner_id': 70, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [70]}
# {'_index': 'meow', '_id': 'prezjkplpe', '_score': None, '_source': {'owner_id': 71, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [71]}
# {'_index': 'meow', '_id': 'fcgtrxayru', '_score': None, '_source': {'owner_id': 78, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [78]}
# {'_index': 'meow', '_id': 'xrmxtdjoce', '_score': None, '_source': {'owner_id': 93, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [93]}
# {'_index': 'meow', '_id': 'qroiymannk', '_score': None, '_source': {'owner_id': 94, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [94]}
# {'_index': 'meow', '_id': 'owoeofkdxh', '_score': None, '_source': {'owner_id': 95, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [95]}
# {'_index': 'meow', '_id': 'hqvgvewknp', '_score': None, '_source': {'owner_id': 96, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [96]}
# {'_index': 'meow', '_id': 'dexwziaatd', '_score': None, '_source': {'owner_id': 102, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [102]}
# {'_index': 'meow', '_id': 'zuvcstqhnf', '_score': None, '_source': {'owner_id': 126, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [126]}
# {'_index': 'meow', '_id': 'sgrvgrphot', '_score': None, '_source': {'owner_id': 134, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [134]}
# {'_index': 'meow', '_id': 'obpmjtgxdb', '_score': None, '_source': {'owner_id': 137, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [137]}
# {'_index': 'meow', '_id': 'luvrzoawfu', '_score': None, '_source': {'owner_id': 151, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [151]}
# {'_index': 'meow', '_id': 'gkriyajyws', '_score': None, '_source': {'owner_id': 154, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [154]}
# {'_index': 'meow', '_id': 'aybtquwyzf', '_score': None, '_source': {'owner_id': 155, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [155]}
# {'_index': 'meow', '_id': 'djbcbxillk', '_score': None, '_source': {'owner_id': 158, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [158]}
# {'_index': 'meow', '_id': 'petxvzcjga', '_score': None, '_source': {'owner_id': 164, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [164]}
# {'_index': 'meow', '_id': 'jgjmrnamdd', '_score': None, '_source': {'owner_id': 171, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [171]}
# {'_index': 'meow', '_id': 'aealszmhwj', '_score': None, '_source': {'owner_id': 177, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [177]}
# {'_index': 'meow', '_id': 'uqunmimxfp', '_score': None, '_source': {'owner_id': 179, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [179]}
# {'_index': 'meow', '_id': 'qinqzipytq', '_score': None, '_source': {'owner_id': 191, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [191]}
# {'_index': 'meow', '_id': 'ydsefwibga', '_score': None, '_source': {'owner_id': 198, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [198]}
# {'_index': 'meow', '_id': 'zvtxdkqort', '_score': None, '_source': {'owner_id': 200, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [200]}
# {'_index': 'meow', '_id': 'fpieilunub', '_score': None, '_source': {'owner_id': 207, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [207]}
# {'_index': 'meow', '_id': 'ljdkziilzf', '_score': None, '_source': {'owner_id': 214, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [214]}
# {'_index': 'meow', '_id': 'ajgynssjes', '_score': None, '_source': {'owner_id': 220, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [220]}
# {'_index': 'meow', '_id': 'patydjszoo', '_score': None, '_source': {'owner_id': 221, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [221]}
# {'_index': 'meow', '_id': 'wvxhimobxl', '_score': None, '_source': {'owner_id': 224, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [224]}
# {'_index': 'meow', '_id': 'hrvcejlhja', '_score': None, '_source': {'owner_id': 227, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [227]}
# {'_index': 'meow', '_id': 'abnpfrejex', '_score': None, '_source': {'owner_id': 234, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [234]}
# {'_index': 'meow', '_id': 'pdncpqcgio', '_score': None, '_source': {'owner_id': 242, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [242]}
# {'_index': 'meow', '_id': 'bhxfvzhlue', '_score': None, '_source': {'owner_id': 243, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [243]}
# {'_index': 'meow', '_id': 'riuyvgvlcb', '_score': None, '_source': {'owner_id': 247, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [247]}
# {'_index': 'meow', '_id': 'wwexdenpdr', '_score': None, '_source': {'owner_id': 262, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [262]}
# {'_index': 'meow', '_id': 'eoegkrtvkg', '_score': None, '_source': {'owner_id': 267, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [267]}
# {'_index': 'meow', '_id': 'ydidxvjfwn', '_score': None, '_source': {'owner_id': 275, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [275]}
# {'_index': 'meow', '_id': 'wzyxyohpao', '_score': None, '_source': {'owner_id': 277, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [277]}
# {'_index': 'meow', '_id': 'dsyjnnmdww', '_score': None, '_source': {'owner_id': 282, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [282]}
# {'_index': 'meow', '_id': 'xbtpmwnocz', '_score': None, '_source': {'owner_id': 284, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [284]}
# {'_index': 'meow', '_id': 'uxfhhxnbcj', '_score': None, '_source': {'owner_id': 293, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [293]}
# {'_index': 'meow', '_id': 'tdtcxsytmw', '_score': None, '_source': {'owner_id': 294, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [294]}
# {'_index': 'meow', '_id': 'zbpalyijjt', '_score': None, '_source': {'owner_id': 317, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [317]}
# {'_index': 'meow', '_id': 'hpdzzcxhzn', '_score': None, '_source': {'owner_id': 324, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [324]}
# {'_index': 'meow', '_id': 'dzzbeobftm', '_score': None, '_source': {'owner_id': 334, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [334]}
# {'_index': 'meow', '_id': 'mhnruixehq', '_score': None, '_source': {'owner_id': 347, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [347]}
# {'_index': 'meow', '_id': 'manbcwhymt', '_score': None, '_source': {'owner_id': 350, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [350]}
# {'_index': 'meow', '_id': 'rpjbsqxyfp', '_score': None, '_source': {'owner_id': 351, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [351]}
# {'_index': 'meow', '_id': 'dgqwvngckq', '_score': None, '_source': {'owner_id': 358, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [358]}
# {'_index': 'meow', '_id': 'shmzfavzzv', '_score': None, '_source': {'owner_id': 362, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [362]}
# {'_index': 'meow', '_id': 'pzmapjxzaw', '_score': None, '_source': {'owner_id': 364, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [364]}
# {'_index': 'meow', '_id': 'gdqtjuacbh', '_score': None, '_source': {'owner_id': 373, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [373]}
# {'_index': 'meow', '_id': 'eptbmebvim', '_score': None, '_source': {'owner_id': 376, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [376]}
# {'_index': 'meow', '_id': 'xxlbtzfxlk', '_score': None, '_source': {'owner_id': 377, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [377]}
# {'_index': 'meow', '_id': 'afqioudjpj', '_score': None, '_source': {'owner_id': 379, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [379]}
# {'_index': 'meow', '_id': 'avfohqkklg', '_score': None, '_source': {'owner_id': 380, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [380]}
# {'_index': 'meow', '_id': 'vlpklgevgi', '_score': None, '_source': {'owner_id': 381, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [381]}
# {'_index': 'meow', '_id': 'rwlorxgpdh', '_score': None, '_source': {'owner_id': 383, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [383]}
# {'_index': 'meow', '_id': 'qfkkbngngc', '_score': None, '_source': {'owner_id': 402, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [402]}
# {'_index': 'meow', '_id': 'hrcjaagpay', '_score': None, '_source': {'owner_id': 427, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [427]}
# {'_index': 'meow', '_id': 'kdywljngsr', '_score': None, '_source': {'owner_id': 428, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [428]}
# {'_index': 'meow', '_id': 'uefuicoeec', '_score': None, '_source': {'owner_id': 434, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [434]}
# {'_index': 'meow', '_id': 'fknvjnlswh', '_score': None, '_source': {'owner_id': 437, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [437]}
# {'_index': 'meow', '_id': 'dluiytnqoi', '_score': None, '_source': {'owner_id': 445, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [445]}
# {'_index': 'meow', '_id': 'vtuozzntom', '_score': None, '_source': {'owner_id': 454, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [454]}
# {'_index': 'meow', '_id': 'endottvueu', '_score': None, '_source': {'owner_id': 466, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [466]}
# {'_index': 'meow', '_id': 'gwphhtklbt', '_score': None, '_source': {'owner_id': 469, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [469]}
# {'_index': 'meow', '_id': 'ecascazpho', '_score': None, '_source': {'owner_id': 475, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [475]}
# {'_index': 'meow', '_id': 'vglfhrvmyd', '_score': None, '_source': {'owner_id': 479, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [479]}
# {'_index': 'meow', '_id': 'wbozefjgkc', '_score': None, '_source': {'owner_id': 486, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [486]}
# {'_index': 'meow', '_id': 'aneightvme', '_score': None, '_source': {'owner_id': 491, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [491]}
# {'_index': 'meow', '_id': 'bfzlzrwepl', '_score': None, '_source': {'owner_id': 495, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [495]}
# {'_index': 'meow', '_id': 'pxebhbqqap', '_score': None, '_source': {'owner_id': 496, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [496]}
# {'_index': 'meow', '_id': 'yvzuvkvfaq', '_score': None, '_source': {'owner_id': 498, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [498]}
# {'_index': 'meow', '_id': 'txertcfjru', '_score': None, '_source': {'owner_id': 510, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [510]}
# {'_index': 'meow', '_id': 'xuqshamxee', '_score': None, '_source': {'owner_id': 512, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [512]}
# {'_index': 'meow', '_id': 'famfdfzsow', '_score': None, '_source': {'owner_id': 520, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [520]}
# {'_index': 'meow', '_id': 'bmwmhlztim', '_score': None, '_source': {'owner_id': 522, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [522]}
# {'_index': 'meow', '_id': 'pkvaumkqoi', '_score': None, '_source': {'owner_id': 536, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [536]}
# {'_index': 'meow', '_id': 'pkucuffogh', '_score': None, '_source': {'owner_id': 540, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [540]}
# {'_index': 'meow', '_id': 'hmfikppdha', '_score': None, '_source': {'owner_id': 546, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [546]}
# {'_index': 'meow', '_id': 'kfsjmjetdt', '_score': None, '_source': {'owner_id': 564, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [564]}
# {'_index': 'meow', '_id': 'nxgwpevjrq', '_score': None, '_source': {'owner_id': 575, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [575]}
# {'_index': 'meow', '_id': 'csmddbwyco', '_score': None, '_source': {'owner_id': 580, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [580]}
# {'_index': 'meow', '_id': 'rvukjotwgm', '_score': None, '_source': {'owner_id': 588, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [588]}
# {'_index': 'meow', '_id': 'gaxslxpghp', '_score': None, '_source': {'owner_id': 602, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [602]}
# {'_index': 'meow', '_id': 'wlvzqfrbyd', '_score': None, '_source': {'owner_id': 604, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [604]}
# {'_index': 'meow', '_id': 'ehkzfogkoh', '_score': None, '_source': {'owner_id': 618, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [618]}
# {'_index': 'meow', '_id': 'yxvbxqlhba', '_score': None, '_source': {'owner_id': 619, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [619]}
# {'_index': 'meow', '_id': 'fduhqvvucp', '_score': None, '_source': {'owner_id': 623, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [623]}
# {'_index': 'meow', '_id': 'iclvmikint', '_score': None, '_source': {'owner_id': 627, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [627]}
# {'_index': 'meow', '_id': 'lmwlkbtmdy', '_score': None, '_source': {'owner_id': 632, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [632]}
# {'_index': 'meow', '_id': 'qjyqrziroo', '_score': None, '_source': {'owner_id': 641, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [641]}
# {'_index': 'meow', '_id': 'oxdydasijz', '_score': None, '_source': {'owner_id': 647, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [647]}
# {'_index': 'meow', '_id': 'jzqurzehin', '_score': None, '_source': {'owner_id': 649, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [649]}
# {'_index': 'meow', '_id': 'csdmlsgjmv', '_score': None, '_source': {'owner_id': 657, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [657]}
# {'_index': 'meow', '_id': 'raqzekrggu', '_score': None, '_source': {'owner_id': 663, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [663]}
# {'_index': 'meow', '_id': 'lhretkxqwi', '_score': None, '_source': {'owner_id': 665, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [665]}
# {'_index': 'meow', '_id': 'atuejoowbw', '_score': None, '_source': {'owner_id': 670, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [670]}
# {'_index': 'meow', '_id': 'iueemduxis', '_score': None, '_source': {'owner_id': 673, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [673]}
# {'_index': 'meow', '_id': 'nljazzwqps', '_score': None, '_source': {'owner_id': 686, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [686]}
# {'_index': 'meow', '_id': 'ypdruqcpkz', '_score': None, '_source': {'owner_id': 688, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [688]}
# {'_index': 'meow', '_id': 'sxtnvgvzhl', '_score': None, '_source': {'owner_id': 691, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [691]}
# {'_index': 'meow', '_id': 'tossymszcm', '_score': None, '_source': {'owner_id': 693, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [693]}
# {'_index': 'meow', '_id': 'xwdhueeaoz', '_score': None, '_source': {'owner_id': 700, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [700]}
# {'_index': 'meow', '_id': 'nskdbavfse', '_score': None, '_source': {'owner_id': 708, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [708]}
# {'_index': 'meow', '_id': 'odfjtjhwdd', '_score': None, '_source': {'owner_id': 720, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [720]}
# {'_index': 'meow', '_id': 'zmrheybpus', '_score': None, '_source': {'owner_id': 722, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [722]}
# {'_index': 'meow', '_id': 'dqaybyukbp', '_score': None, '_source': {'owner_id': 730, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [730]}
# {'_index': 'meow', '_id': 'wrhmndotdg', '_score': None, '_source': {'owner_id': 732, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [732]}
# {'_index': 'meow', '_id': 'ukxziljcsb', '_score': None, '_source': {'owner_id': 734, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [734]}
# {'_index': 'meow', '_id': 'waouldxald', '_score': None, '_source': {'owner_id': 753, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [753]}
# {'_index': 'meow', '_id': 'vobddhidgv', '_score': None, '_source': {'owner_id': 758, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [758]}
# {'_index': 'meow', '_id': 'sxdkebhsgz', '_score': None, '_source': {'owner_id': 761, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [761]}
# {'_index': 'meow', '_id': 'bbmpmwvgey', '_score': None, '_source': {'owner_id': 768, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [768]}
# {'_index': 'meow', '_id': 'xnyezyfryj', '_score': None, '_source': {'owner_id': 769, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [769]}
# {'_index': 'meow', '_id': 'hujdxlauou', '_score': None, '_source': {'owner_id': 772, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [772]}
# {'_index': 'meow', '_id': 'mnlmfxqgio', '_score': None, '_source': {'owner_id': 776, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [776]}
# {'_index': 'meow', '_id': 'plpvsvagfy', '_score': None, '_source': {'owner_id': 777, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [777]}
# {'_index': 'meow', '_id': 'ewjdlczquy', '_score': None, '_source': {'owner_id': 785, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [785]}
# {'_index': 'meow', '_id': 'fbhfqwjtvf', '_score': None, '_source': {'owner_id': 795, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [795]}
# {'_index': 'meow', '_id': 'evjnukunbq', '_score': None, '_source': {'owner_id': 797, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [797]}
# {'_index': 'meow', '_id': 'bgxtspfhpx', '_score': None, '_source': {'owner_id': 807, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [807]}
# {'_index': 'meow', '_id': 'fkbpkiylgy', '_score': None, '_source': {'owner_id': 809, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [809]}
# {'_index': 'meow', '_id': 'mvxrpcnaun', '_score': None, '_source': {'owner_id': 815, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [815]}
# {'_index': 'meow', '_id': 'zaxbjdayat', '_score': None, '_source': {'owner_id': 818, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [818]}
# {'_index': 'meow', '_id': 'zptzhxviik', '_score': None, '_source': {'owner_id': 822, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [822]}
# {'_index': 'meow', '_id': 'duzspjxnqj', '_score': None, '_source': {'owner_id': 835, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [835]}
# {'_index': 'meow', '_id': 'jsrmxbjify', '_score': None, '_source': {'owner_id': 853, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [853]}
# {'_index': 'meow', '_id': 'akccyqudkx', '_score': None, '_source': {'owner_id': 871, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [871]}
# {'_index': 'meow', '_id': 'jeizmnkimn', '_score': None, '_source': {'owner_id': 889, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [889]}
# {'_index': 'meow', '_id': 'mwaqfwbqcd', '_score': None, '_source': {'owner_id': 891, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [891]}
# {'_index': 'meow', '_id': 'tgxgliqwag', '_score': None, '_source': {'owner_id': 898, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [898]}
# {'_index': 'meow', '_id': 'bcrmedsvgq', '_score': None, '_source': {'owner_id': 900, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [900]}
# {'_index': 'meow', '_id': 'kvkgbhpybn', '_score': None, '_source': {'owner_id': 904, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [904]}
# {'_index': 'meow', '_id': 'rctidnrsaq', '_score': None, '_source': {'owner_id': 905, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [905]}
# {'_index': 'meow', '_id': 'hgwtljhskp', '_score': None, '_source': {'owner_id': 913, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [913]}
# {'_index': 'meow', '_id': 'wsfvjqrdbk', '_score': None, '_source': {'owner_id': 921, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [921]}
# {'_index': 'meow', '_id': 'fslhwhjgcp', '_score': None, '_source': {'owner_id': 922, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [922]}
# {'_index': 'meow', '_id': 'pwzkbfrokl', '_score': None, '_source': {'owner_id': 923, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [923]}
# {'_index': 'meow', '_id': 'wsgtbarazl', '_score': None, '_source': {'owner_id': 947, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [947]}
# {'_index': 'meow', '_id': 'znkrvomkeh', '_score': None, '_source': {'owner_id': 954, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [954]}
# {'_index': 'meow', '_id': 'smpdxmxbqh', '_score': None, '_source': {'owner_id': 961, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [961]}
# {'_index': 'meow', '_id': 'hordojtgdy', '_score': None, '_source': {'owner_id': 962, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [962]}
# {'_index': 'meow', '_id': 'dbwslgfmpp', '_score': None, '_source': {'owner_id': 971, 'pets': {'cats': 3, 'dogs': 5}}, 'sort': [971]}
# {'_index': 'meow', '_id': 'khlhkmoofk', '_score': None, '_source': {'owner_id': 975, 'pets': {'cats': 3, 'dogs': 2}}, 'sort': [975]}
# {'_index': 'meow', '_id': 'mcysqqtlke', '_score': None, '_source': {'owner_id': 976, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [976]}
# {'_index': 'meow', '_id': 'femznalmer', '_score': None, '_source': {'owner_id': 980, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [980]}
# {'_index': 'meow', '_id': 'ujmqkkdzxy', '_score': None, '_source': {'owner_id': 986, 'pets': {'cats': 3, 'dogs': 4}}, 'sort': [986]}
# {'_index': 'meow', '_id': 'exhgeoqzso', '_score': None, '_source': {'owner_id': 990, 'pets': {'cats': 3, 'dogs': 1}}, 'sort': [990]}
# {'_index': 'meow', '_id': 'opcgzppqoo', '_score': None, '_source': {'owner_id': 993, 'pets': {'cats': 3, 'dogs': 0}}, 'sort': [993]}
# {'_index': 'meow', '_id': 'csvjaherha', '_score': None, '_source': {'owner_id': 995, 'pets': {'cats': 3, 'dogs': 3}}, 'sort': [995]}
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
docs_response
# Out:
# <generator object scan at 0x7fdfb3b9a7b0>
