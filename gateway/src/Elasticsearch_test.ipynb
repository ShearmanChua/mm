# %%
import os
from typing import Optional, List, Dict

from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk, scan, streaming_bulk

# %%
type_map = {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
def traverse_map (map_dict):
    original_map_dict = dict(map_dict)
    for k, v in map_dict.items():
        if isinstance(v, dict):
            traverse_map(v)
        else:
            try:
                map_dict[k] = {"type":TYPE_MAP[v.lower()]}
            except Exception as e:
                print(f'{e.__class__.__name__}: Key {v} not found in TYPE_MAP. Mapping not updated')
                return original_map_dict
    return map_dict

# %%
TYPE_MAP =  {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
user_map = {
    "name":"str",
    "age":"int",
    "education":{
        "primary":{
            "school":"str"
        },
        "secondary":"str",
        "tertiary":"str"
    }
}

# %%
final_map = {"mappings":{"properties":{}}}

# %%
updated_map = traverse_map(user_map)
# Out:
# KeyError: Key meow not found in TYPE_MAP. Mapping not updated

# %%
updated_map
# Out:
# {'name': {'type': 'text'},
#  'age': {'type': 'integer'},
#  'education': {'primary': {'school': 'meow'},
#   'secondary': {'type': 'text'},
#   'tertiary': {'type': 'text'}}}

# %%
TYPE_MAP =  {
    "int":"integer",
    "float":"float",
    "double":"double",
    "str": "text",
    "bool": "boolean",
    "datetime": "date",
    "list[int]":"integer",
    "list[str]":"text",
    "list[float]": "float",
    "list[double]": "double",
    "torch.tensor": "dense_vector",
    "numpy.ndarray": "dense_vector"
}

# %%
user_map = {
    "name":"str",
    "age":"int",
    "education":{
        "primary":{
            "school":"str"
        },
        "secondary":"str",
        "tertiary":"str"
    }
}

user_map = {
    "owner_name": "str",
    "owner_id": "str",
    "cats": "int",
    "dogs": "int"
}

# %%
MAX_BULK_SIZE=10000
class DocMgr():
    
    
    def __init__(self):
        self.url = f"https://{os.environ.get('ELASTICSEARCH_HOST')}:{os.environ.get('ELASTICSEARCH_C_PORT')}"
        self.username = os.environ.get('ELASTIC_USERNAME')
        self.password = os.environ.get('ELASTIC_PASSWORD')
        self.client = Elasticsearch(self.url, 
                                    verify_certs=False, 
                                    basic_auth=(self.username, self.password))
        
        self.consolidated_actions=[]

        
    def _check_valid_values(self, map_dict:dict) -> int:
        """
        Traverse mapping dictionary to ensure that all types are valid types within TYPE_MAP

        Args:
            map_dict (dict): Mapping to be checked

        Returns:
            int: 0 if there is invalid types, 1 otherwise

        """
        ret_val = 1
        for k, v in map_dict.items():
            if isinstance(v, dict):
                ret_val = self._check_valid_values(v)
            else:
                if not v in TYPE_MAP:
                    print(f"'{v}' type for '{k}' NOT FOUND")
                    return 0

        return ret_val * 1
    
    def _traverse_map (self, map_dict:Dict) -> Dict:
        """
        Traverse mapping dictionary to convert data type into framework specific type

        Args:
            map_dict (dict): Mapping to be used to create ES index

        Returns:
            dict: updated mapping dictionary

        """
        dictionary ={"properties":dict()}
        for k, v in map_dict.items():
            if isinstance(v, dict):
                dictionary['properties'][k]= self._traverse_map(v)
            else:
                dictionary['properties'][k]={"type":TYPE_MAP[v]}       
        return dictionary
    
    def _flush(self):
        errors = []
        list_of_es_ids = []
        for ok, item in streaming_bulk(self.client, self.consolidated_actions):
            if not ok:
                errors.append(item)
            else:
                list_of_es_ids.append(item['index']['_id'])
        print("List of faulty documents:", errors)
        self.consolidated_actions=[] # Reset List
        return list_of_es_ids
        
    
    def create_collection(self, collection_name: str, schema: Dict) -> Dict:
        """
        Create the index on ElasticSearch

        Args:
            collection_name (str): Index name of ES
            schema (dict): Mapping to be used to create ES index

        Returns:
            dict: response of error, or 200 if no errors caught
            
        """
        try:
            assert type(schema)==dict
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'schema' is not dict"}
        try:
            assert type(collection_name)==str
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'collection_name' is not str"}

        mapping_validity = self._check_valid_values(schema)
        if not mapping_validity:
            return {"response": "KeyError: data type not found in TYPE_MAP"}
        updated_mapping = self._traverse_map(schema)
        try:
            self.client.indices.create(index=collection_name, mappings=updated_mapping)
        except Exception as e:
            return {"response":f"{e}"}
        return {"response":"200"}
    
    def delete_collection(self, collection_name: str) -> dict:
        """
        Create the index on ElasticSearch

        Args:
            collection_name (str): Index name of ES
            schema (dict): Mapping to be used to create ES index

        Returns:
            dict: response of error, or 200 if no errors caught

        """
        try:
            self.client.indices.delete(index=collection_name)
        except Exception as e:
            return {"response": f"{e}"}
        return {"response":"200"}
    
    def create_document(self, collection_name: str, documents: List[Dict], id_field: str=None) -> dict:
        """
        Upload document(s) in the specified index within ElasticSearch

        Args:
            collection_name (str): Index name of ES
            documents (list): A list of document objects to be ingested
            id_field (str): specify the key amongst the document object to be the id field. If not specified, id will be generated by ES. 

        Returns:
            dict: response of error along with the faulty document, or 200 along with the ids of ingested document if no errors caught

        """
        try:
            assert type(documents)==list
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'documents' is not dict"}
        try:
            assert type(collection_name)==str
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'collection_name' is not str"}
        if not id_field is None:
            try:
                assert type(id_field)==str
            except Exception as e:
                return {"response":f"{e.__class__.__name__}: Type of 'id_field' is not str"}
        
        # If id_field is specified, verify that all documents possess the id_field. 
        if id_field != None:
            for doc in documents:
                if not id_field in doc.keys():
                    print("Fix document, or set 'id_field' to None. No documents uploaded.")
                    return {"response": "Fix document, or set 'id_field' to None. No documents uploaded.",
                           "error_doc": doc}
                try:
                    doc[id_field] = str(doc[id_field])
                except Exception as e:
                    return {"response": f"{e.__class__.__name__}: id cannot be casted to String type. No documents uploaded.",
                           "error_doc": doc}
        all_id = []
        for doc in documents:
            action_dict={}
            action_dict['_op_type']= 'index'
            action_dict['_index']=collection_name
            if id_field != None:
                action_dict['_id']=doc[id_field]
                doc.pop(id_field)
            action_dict['_source']=doc
            self.consolidated_actions.append(action_dict)
            if len(self.consolidated_actions) == MAX_BULK_SIZE:
                all_id = all_id+self._flush()
        
        all_id = all_id+self._flush()
        
        return {"response":"200", "ids": all_id}
    
    def delete_document(self, collection_name: str, doc_id:str) -> dict:
        """
        Delete document from index based on the specified document id. 

        Args:
            collection_name (str): Index name of ES
            doc_id (str): id of doc to be deleted

        Returns:
            dict: response of error along with the faulty document, or 200 along with elastic API response

        """
        try:
            assert type(collection_name)==str
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'collection_name' is not str"}
        try:
            assert type(doc_id)==str
        except Exception as e:
            return {"response":f"{e.__class__.__name__}: Type of 'doc_id' is not str"}
        
        # Check for document's existence     
        search_result = self.client.search(index="meow", query={"match":{"_id":doc_id}})
        result_count = search_result['hits']['total']['value']
        
        if result_count == 0:
            return {"response": f"Document '{doc_id}' not found!"}
        
        try:
            resp = self.client.delete(index="meow", id=doc_id)
        except Exception as e:
            return {"response":f"{e.__class__.__name__}. Document Deletion failed"}
        
        return {"response":"200", "api_resp": resp}

# %%
es_mgr = DocMgr()

# %%
create_res = es_mgr.create_collection(collection_name = "meow", schema = user_map)
print(create_res)
# Out:
# {'response': '200'}
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
del_res = es_mgr.delete_collection("meow")
print(del_res)
# Out:
# {'response': '200'}
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
def create_document(collection_name: str, properties: list, id_name:str=None) -> dict:
    print(collection_name)
    print(properties)
    print(id_name)

# %%
import random
import string

# printing lowercase

rand_data = []
user_map = {
    "owner_name": "str",
    "owner_id": "str",
    "cats": "int",
    "dogs": "int"
}

letters = string.ascii_lowercase
for i in range(1000):
    fake_data = {}
    fake_data["owner_name"] = ''.join(random.choice(letters) for i in range(10))
    fake_data['owner_id'] = i
    fake_data['cats'] = random.randint(0,5)
    fake_data['dogs'] = random.randint(0,5)
    rand_data.append(fake_data)

# %%
rand_data
# Out:
# [{'owner_name': 'kblgshxteh', 'owner_id': 0, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'aaxvguzxkc', 'owner_id': 1, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'gkusonhnei', 'owner_id': 2, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'yrpipvshmb', 'owner_id': 3, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'pxoenthvef', 'owner_id': 4, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'zcztimhdfc', 'owner_id': 5, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'xudyjrzhyq', 'owner_id': 6, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'yqlbdeinhs', 'owner_id': 7, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'iougvaeudd', 'owner_id': 8, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'btwiuyhitw', 'owner_id': 9, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'zvztpvacpn', 'owner_id': 10, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'dakorqhbzt', 'owner_id': 11, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'fbithftyym', 'owner_id': 12, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'vdwfhtjkxu', 'owner_id': 13, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'vqnzbthqyj', 'owner_id': 14, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'xsjbbeftfm', 'owner_id': 15, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'qbubhwpalg', 'owner_id': 16, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'gmflvqeqck', 'owner_id': 17, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'tomyimptuc', 'owner_id': 18, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'tbwasnssuv', 'owner_id': 19, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'dtckbpybrk', 'owner_id': 20, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'oyuxkoygud', 'owner_id': 21, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'rcxbskvbza', 'owner_id': 22, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'gdpqxeymgg', 'owner_id': 23, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'bzakkbkqqj', 'owner_id': 24, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'oelcddqicl', 'owner_id': 25, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'qtembadsbg', 'owner_id': 26, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'enkbjxewxa', 'owner_id': 27, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'umlahuxqtk', 'owner_id': 28, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'folppzcclg', 'owner_id': 29, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'utlpgmohzv', 'owner_id': 30, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'nvzblwopbs', 'owner_id': 31, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'xehxmgymql', 'owner_id': 32, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'hdvjtgthwf', 'owner_id': 33, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'ksozydulur', 'owner_id': 34, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'qzodwgyssw', 'owner_id': 35, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'ntbnvzgkvv', 'owner_id': 36, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'uzdzixnesp', 'owner_id': 37, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'jvvaunazty', 'owner_id': 38, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'zejtcdfgns', 'owner_id': 39, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'slqyschhou', 'owner_id': 40, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'spiellxzyq', 'owner_id': 41, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'ooejywhfbw', 'owner_id': 42, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'nxrdbvofwb', 'owner_id': 43, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'ougxbhmufd', 'owner_id': 44, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ohaedlqado', 'owner_id': 45, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'bprbzkjlhs', 'owner_id': 46, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'krpdnskysn', 'owner_id': 47, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'rwdjxrgcvw', 'owner_id': 48, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'hsizdptvfx', 'owner_id': 49, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'mxmbizirzc', 'owner_id': 50, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'cyzfmkiaks', 'owner_id': 51, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'qzjvqhknrf', 'owner_id': 52, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'adaitpdvrh', 'owner_id': 53, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'rgfjuwjgwh', 'owner_id': 54, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'xmxcdrxcru', 'owner_id': 55, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'rusinxuatm', 'owner_id': 56, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'jxmvvnkvud', 'owner_id': 57, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'nbnmakqkfx', 'owner_id': 58, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'ueywjdoats', 'owner_id': 59, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'hyuxotdyhk', 'owner_id': 60, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'oqitovldln', 'owner_id': 61, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ztawzujnet', 'owner_id': 62, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'fngisisxyq', 'owner_id': 63, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'gzkoakycme', 'owner_id': 64, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'gmtkwtsdzo', 'owner_id': 65, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'ydwtnnihfm', 'owner_id': 66, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'figamvpobt', 'owner_id': 67, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'piofqjqaoa', 'owner_id': 68, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'qxyuijikbg', 'owner_id': 69, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'tlccvzwkcr', 'owner_id': 70, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ujiveefjct', 'owner_id': 71, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'wijeuxmkzu', 'owner_id': 72, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'zcmiwffxif', 'owner_id': 73, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'kgcxhzpipp', 'owner_id': 74, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'xdisbyzlxs', 'owner_id': 75, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'xaniqnknrh', 'owner_id': 76, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'gpqzcroiwa', 'owner_id': 77, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'fkiouandvb', 'owner_id': 78, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'nnnpnkddhx', 'owner_id': 79, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'mxlzojwfav', 'owner_id': 80, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'ylrkhlahlx', 'owner_id': 81, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'gdzdijzzph', 'owner_id': 82, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'wwssjaalpk', 'owner_id': 83, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'eosnfgbfui', 'owner_id': 84, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'jlbwzdxvlj', 'owner_id': 85, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'hvjzpudeph', 'owner_id': 86, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'ddlwicxkpa', 'owner_id': 87, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'ghhxdgahzm', 'owner_id': 88, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'tlemjqmjxa', 'owner_id': 89, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'nwuzriqqcn', 'owner_id': 90, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'trlupjotrh', 'owner_id': 91, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'iikerznsdf', 'owner_id': 92, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'mjvsaxmdco', 'owner_id': 93, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'nhhllrsjxe', 'owner_id': 94, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'tvwppipovl', 'owner_id': 95, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'kwcmmleyph', 'owner_id': 96, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'tnvmrbaeyp', 'owner_id': 97, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'dlxaxceykc', 'owner_id': 98, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'fyhonqrlro', 'owner_id': 99, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'ggnipoqxth', 'owner_id': 100, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'cbehvluwgl', 'owner_id': 101, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'cgsfnmrszc', 'owner_id': 102, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'bvdqhgjaau', 'owner_id': 103, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'ifrhstxvxu', 'owner_id': 104, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'bocbouqiaa', 'owner_id': 105, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'yupwfyfscg', 'owner_id': 106, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'ecnquivtgh', 'owner_id': 107, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'yyxqxjyjsg', 'owner_id': 108, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'hugvzoypks', 'owner_id': 109, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'zxpyelreuk', 'owner_id': 110, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'fthgydeppv', 'owner_id': 111, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'wkmehphxwl', 'owner_id': 112, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'wnwrhxdyal', 'owner_id': 113, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'clhqlglpdo', 'owner_id': 114, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'zcjtvrdtjh', 'owner_id': 115, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'pcrejitpur', 'owner_id': 116, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'gfjxkwmgve', 'owner_id': 117, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'iurpyblawf', 'owner_id': 118, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'xsyclqyhik', 'owner_id': 119, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'eexiofzuws', 'owner_id': 120, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'ugtllitvza', 'owner_id': 121, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'pdrfoeywzb', 'owner_id': 122, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'ahxwfheqjy', 'owner_id': 123, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'mqfncipgyq', 'owner_id': 124, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'wckcukztjz', 'owner_id': 125, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'mciqhjtmkk', 'owner_id': 126, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'llajbgyzvn', 'owner_id': 127, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'hjtojzzaes', 'owner_id': 128, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'gattgvjrqf', 'owner_id': 129, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'xcshtwvjht', 'owner_id': 130, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'hgfcjoukuq', 'owner_id': 131, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'bicowkioxz', 'owner_id': 132, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'mpelmjyfqt', 'owner_id': 133, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'xqsltgiuoc', 'owner_id': 134, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'cqfedtnwye', 'owner_id': 135, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'yomsajapye', 'owner_id': 136, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'dhjpdxplty', 'owner_id': 137, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'hjkiavtwzm', 'owner_id': 138, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'nqsibjztzf', 'owner_id': 139, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'sfnkwlojht', 'owner_id': 140, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'pczheocvms', 'owner_id': 141, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'oekgdcawxx', 'owner_id': 142, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'nostnebisz', 'owner_id': 143, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'emorneegaz', 'owner_id': 144, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'ebhryggdmw', 'owner_id': 145, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'mfxaaksvcp', 'owner_id': 146, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'nxyxlatjeu', 'owner_id': 147, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'aajdrlaaga', 'owner_id': 148, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'xtxtnouzop', 'owner_id': 149, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'tghzjrpnmn', 'owner_id': 150, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'dqorkrfvbt', 'owner_id': 151, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'afelelrfjd', 'owner_id': 152, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'yyardwrljc', 'owner_id': 153, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'mwcksghchr', 'owner_id': 154, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'oijdfbvqdh', 'owner_id': 155, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'tdoexzxenp', 'owner_id': 156, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'bnwdoyvrby', 'owner_id': 157, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'nllufcimua', 'owner_id': 158, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'cjcskrhben', 'owner_id': 159, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'folncxrthe', 'owner_id': 160, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'kffaqpoihv', 'owner_id': 161, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'sojpbqoreq', 'owner_id': 162, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'lxptuprhkd', 'owner_id': 163, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'aqvnmmtive', 'owner_id': 164, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'lluwonznlx', 'owner_id': 165, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'bgaisseinc', 'owner_id': 166, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'uzkhledutj', 'owner_id': 167, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'vrphqhuxwa', 'owner_id': 168, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'tcgruygwwp', 'owner_id': 169, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'qpmwlizzpt', 'owner_id': 170, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'wisdsilljd', 'owner_id': 171, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'ocngabklql', 'owner_id': 172, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'wbgredlfqb', 'owner_id': 173, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'qrwdkxqriz', 'owner_id': 174, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'wkppjxcuct', 'owner_id': 175, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'xruycjtvrx', 'owner_id': 176, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'vudogxuvti', 'owner_id': 177, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'qdhmooxkqw', 'owner_id': 178, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'islbxjakpc', 'owner_id': 179, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'mkaywmignx', 'owner_id': 180, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'scuombotyy', 'owner_id': 181, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'cwfrejsmvw', 'owner_id': 182, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'qfdgzbxzxv', 'owner_id': 183, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'cjiejarrzu', 'owner_id': 184, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'czojzacmid', 'owner_id': 185, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'eurbzxexhm', 'owner_id': 186, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'ummrrcweow', 'owner_id': 187, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'vlpkiqbdkl', 'owner_id': 188, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'iqqolaeddj', 'owner_id': 189, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'pzlyvmzexl', 'owner_id': 190, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'bcfelajnse', 'owner_id': 191, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'bowbguesmj', 'owner_id': 192, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'shibkhvijm', 'owner_id': 193, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'zypygkhjml', 'owner_id': 194, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'hagnstucdv', 'owner_id': 195, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'nsjbbrkser', 'owner_id': 196, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'gmpuytcgtg', 'owner_id': 197, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'yzknhkefrq', 'owner_id': 198, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'wuwmkqyjtz', 'owner_id': 199, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'dbmmplckwq', 'owner_id': 200, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'emllxnqffn', 'owner_id': 201, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'bqdlqilmtz', 'owner_id': 202, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'dctcpytdmh', 'owner_id': 203, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'udordbmapt', 'owner_id': 204, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'rnllnledrt', 'owner_id': 205, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'mukbiwplzl', 'owner_id': 206, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'ijrouxpvup', 'owner_id': 207, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'nhjdmworyi', 'owner_id': 208, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'mefpcmhatl', 'owner_id': 209, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'qssobxdilg', 'owner_id': 210, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'tmismcyeww', 'owner_id': 211, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'gfyxgfgnzv', 'owner_id': 212, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'kcqpurdyxi', 'owner_id': 213, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'xqfnetlxbd', 'owner_id': 214, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'djjuphkvgl', 'owner_id': 215, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'lzzjujmlvv', 'owner_id': 216, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'xvqdnkmvli', 'owner_id': 217, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'xvsdcmjorw', 'owner_id': 218, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'ylmibyndsy', 'owner_id': 219, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'hwpygfookp', 'owner_id': 220, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'zbuefaqsio', 'owner_id': 221, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'ulsvdmrtyy', 'owner_id': 222, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'uuqzuugsby', 'owner_id': 223, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'edetxldkzb', 'owner_id': 224, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'dkavrimyhf', 'owner_id': 225, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'kottsuzdfl', 'owner_id': 226, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'xtoqjvfhwj', 'owner_id': 227, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'wjcvzvfean', 'owner_id': 228, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'iuwyupmhtn', 'owner_id': 229, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'ttpxacpyki', 'owner_id': 230, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'lnszbzrqyr', 'owner_id': 231, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'vqodrdkaqe', 'owner_id': 232, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'xzjwvcoutd', 'owner_id': 233, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'nkpmfwuwja', 'owner_id': 234, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'hbtthomvzk', 'owner_id': 235, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'zslhzfbcoz', 'owner_id': 236, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'ybudcbttku', 'owner_id': 237, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'yzhgetnicg', 'owner_id': 238, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'jeehbdiqua', 'owner_id': 239, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'ycrjrbanxq', 'owner_id': 240, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'ztxzvjkgcz', 'owner_id': 241, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'xsqngsgtbg', 'owner_id': 242, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'ksuvndguch', 'owner_id': 243, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'jlkvshdgam', 'owner_id': 244, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'lxgpdruqnn', 'owner_id': 245, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'hemrdgellm', 'owner_id': 246, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'mayjdglfpy', 'owner_id': 247, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'xmdyrebfza', 'owner_id': 248, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'wbaeeaknrw', 'owner_id': 249, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'llcvwhjueq', 'owner_id': 250, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'znydgjadze', 'owner_id': 251, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'snbjgowxdd', 'owner_id': 252, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'uujdciyyfk', 'owner_id': 253, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'iubdvqzjzw', 'owner_id': 254, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'yofvcmxyxp', 'owner_id': 255, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'hdvhbtseam', 'owner_id': 256, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'yefrqjttfa', 'owner_id': 257, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'uqyexucrpf', 'owner_id': 258, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'lurzpknpcq', 'owner_id': 259, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'kilygfwcmy', 'owner_id': 260, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'zwipozkkns', 'owner_id': 261, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'hoqtjbumbl', 'owner_id': 262, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'oapoizbmxe', 'owner_id': 263, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'uhckuyurpc', 'owner_id': 264, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'potgpjagim', 'owner_id': 265, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'ajzpxxlcqi', 'owner_id': 266, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'xzhzndemtp', 'owner_id': 267, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'ktyrezxosw', 'owner_id': 268, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'qhledgsgcs', 'owner_id': 269, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'kjidyxvvdx', 'owner_id': 270, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'cntcympwcc', 'owner_id': 271, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'sszxmofjfb', 'owner_id': 272, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'smucwxsnim', 'owner_id': 273, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'sideguzgms', 'owner_id': 274, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'orqtkuzwhl', 'owner_id': 275, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'jjbjllfgxs', 'owner_id': 276, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'psqdauboek', 'owner_id': 277, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'yfoerujtfj', 'owner_id': 278, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'aabcyglgig', 'owner_id': 279, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ntuwgpfwhq', 'owner_id': 280, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'rbcmwbrstg', 'owner_id': 281, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'uscfrgwodl', 'owner_id': 282, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'gssfhqynsd', 'owner_id': 283, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'rdtcmlfihm', 'owner_id': 284, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'skxtwwultx', 'owner_id': 285, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'nodafxoorq', 'owner_id': 286, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'ripiomczjq', 'owner_id': 287, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'huoewmbfhv', 'owner_id': 288, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'ofubfldjob', 'owner_id': 289, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'jxlfdbmomy', 'owner_id': 290, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'fqdmxsotcf', 'owner_id': 291, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'qzrekjbxns', 'owner_id': 292, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'gigavptqdk', 'owner_id': 293, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'patpfrtnpi', 'owner_id': 294, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'wpvumfzgdb', 'owner_id': 295, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'xitmdykimy', 'owner_id': 296, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'lmxobmwdyd', 'owner_id': 297, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'tcbqrlrmuh', 'owner_id': 298, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'fohazqrdpa', 'owner_id': 299, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'jqjufrpjhc', 'owner_id': 300, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'iwwqmlslwy', 'owner_id': 301, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'vmhfebcubq', 'owner_id': 302, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'zodnwepkxo', 'owner_id': 303, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'vnanwbgenw', 'owner_id': 304, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'lbqxubwzrh', 'owner_id': 305, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'srelkjinaa', 'owner_id': 306, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'bawshwbjgo', 'owner_id': 307, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'kuiehootha', 'owner_id': 308, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'limfgpodze', 'owner_id': 309, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'qoydrtpsis', 'owner_id': 310, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'shpfpdluac', 'owner_id': 311, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'enoetdrvig', 'owner_id': 312, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'hohdqdnmec', 'owner_id': 313, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'zfqgpsyvtj', 'owner_id': 314, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'pkzhiaadqb', 'owner_id': 315, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'ztxjunwtii', 'owner_id': 316, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'albhuezdni', 'owner_id': 317, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'ndvmsacdpb', 'owner_id': 318, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'erqwgwmlwk', 'owner_id': 319, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'mnaojeligj', 'owner_id': 320, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'sychoobtmy', 'owner_id': 321, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'diloipvqzl', 'owner_id': 322, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'axgtlikfst', 'owner_id': 323, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'zjhjpsmpjc', 'owner_id': 324, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'vdzgzsuhez', 'owner_id': 325, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'pfnkuzputg', 'owner_id': 326, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'jeagvtmfgj', 'owner_id': 327, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'vuksiypzmj', 'owner_id': 328, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'jpieohbhel', 'owner_id': 329, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'zdjrjeabje', 'owner_id': 330, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'gustljrypq', 'owner_id': 331, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'jyhatjwocp', 'owner_id': 332, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'jxquipwotd', 'owner_id': 333, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'usniwqffib', 'owner_id': 334, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'umsebdudew', 'owner_id': 335, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'aamtnggmkn', 'owner_id': 336, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'kgtsjlewqa', 'owner_id': 337, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'emsqifdvur', 'owner_id': 338, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'liyqzlfbqv', 'owner_id': 339, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'mvvupbdqfe', 'owner_id': 340, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'slgeqluxbt', 'owner_id': 341, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'jpbxgpyuub', 'owner_id': 342, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'fvwbplscon', 'owner_id': 343, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'kinqlwryep', 'owner_id': 344, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'qmveglcsjn', 'owner_id': 345, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'ezxuumixqy', 'owner_id': 346, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'cqpocysznj', 'owner_id': 347, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'bxidojiajg', 'owner_id': 348, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'lgmjxudnpx', 'owner_id': 349, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'bcwklamuxo', 'owner_id': 350, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'tfmzamuqhb', 'owner_id': 351, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'knpghuispe', 'owner_id': 352, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'zsmfgxtjim', 'owner_id': 353, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'xyeiivmyqj', 'owner_id': 354, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'shwfpytjkc', 'owner_id': 355, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'tchwwmrlxy', 'owner_id': 356, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'dicuzbrevo', 'owner_id': 357, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'nagnpbmchs', 'owner_id': 358, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'txljdiwxry', 'owner_id': 359, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'ksnvesdvuh', 'owner_id': 360, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'ntnsevymqa', 'owner_id': 361, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'cvaypbyntu', 'owner_id': 362, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'ziiykytrrx', 'owner_id': 363, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'utomiqkzla', 'owner_id': 364, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'gcdegrjzsh', 'owner_id': 365, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'erovepyihf', 'owner_id': 366, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'kdzcybvsqz', 'owner_id': 367, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'eoprwohppk', 'owner_id': 368, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'uhlaafmjxl', 'owner_id': 369, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'zkavesrznx', 'owner_id': 370, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'nozxnjcpcn', 'owner_id': 371, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'xacbeuztdd', 'owner_id': 372, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'yxynehrqxq', 'owner_id': 373, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'kgadoyzyzt', 'owner_id': 374, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'vunjdlqpky', 'owner_id': 375, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'yjslmcgrcg', 'owner_id': 376, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'mvhshhnzoj', 'owner_id': 377, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'qnxwtfmstw', 'owner_id': 378, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'ebmxxysxlr', 'owner_id': 379, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ewygxaerrj', 'owner_id': 380, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'pcopjiwasz', 'owner_id': 381, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'ogdmhxlxbc', 'owner_id': 382, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'khgumimlzr', 'owner_id': 383, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'bchvswusmk', 'owner_id': 384, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'ngikgczxhj', 'owner_id': 385, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'fhroidkzrp', 'owner_id': 386, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'wyzmhaokqx', 'owner_id': 387, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'ffzakqpuiy', 'owner_id': 388, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'jpkwvixbnu', 'owner_id': 389, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'trdnfrrpqr', 'owner_id': 390, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'wxpsmjajld', 'owner_id': 391, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'rlfqggrveu', 'owner_id': 392, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'fgymlztdwa', 'owner_id': 393, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'wflojlazkh', 'owner_id': 394, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'ujxgrcawbm', 'owner_id': 395, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'pmsaneasyo', 'owner_id': 396, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'uclvditrwr', 'owner_id': 397, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'jrgrfidquc', 'owner_id': 398, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'zcqzxcbmiq', 'owner_id': 399, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'cfxbmrwdzw', 'owner_id': 400, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'cohugzfyxq', 'owner_id': 401, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'dpryasgqct', 'owner_id': 402, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'ubygulsqrw', 'owner_id': 403, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'myxxjeyucb', 'owner_id': 404, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'ixpghidzbn', 'owner_id': 405, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'ougtonrsrs', 'owner_id': 406, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'uwfflwyxgu', 'owner_id': 407, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'apujrffbkc', 'owner_id': 408, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'fxnwpewryi', 'owner_id': 409, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'cgqfhqnnos', 'owner_id': 410, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'tbnpjqyquk', 'owner_id': 411, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'aexzhzkcdm', 'owner_id': 412, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'akxumgstua', 'owner_id': 413, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'rzmmbzyznh', 'owner_id': 414, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'nccvzzcrqw', 'owner_id': 415, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'zbptkhrkkg', 'owner_id': 416, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'ftbkatgmew', 'owner_id': 417, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'hlptbphvgc', 'owner_id': 418, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'ugdlebwinp', 'owner_id': 419, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'oyzkqevuud', 'owner_id': 420, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'yjfvnsxwzh', 'owner_id': 421, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'tcghpnzdfo', 'owner_id': 422, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'jwmcmxunes', 'owner_id': 423, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'oslxvrorqh', 'owner_id': 424, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'npqwraptah', 'owner_id': 425, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'zqzutbuswu', 'owner_id': 426, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'gfmtxghafu', 'owner_id': 427, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'lmwhaxbtwp', 'owner_id': 428, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'afyvwavotg', 'owner_id': 429, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'xgkwrhdwqi', 'owner_id': 430, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'uipiihergz', 'owner_id': 431, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'qhxoqidsoi', 'owner_id': 432, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'kztljlojmp', 'owner_id': 433, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'sherkoslqw', 'owner_id': 434, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'mehuogykej', 'owner_id': 435, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'hkjatgaine', 'owner_id': 436, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'feytrbxlst', 'owner_id': 437, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'xcwkioxnbe', 'owner_id': 438, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'oqvomnxfvn', 'owner_id': 439, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'ekyadrgyvg', 'owner_id': 440, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'ivjtfrqwai', 'owner_id': 441, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'mjqwtxmhag', 'owner_id': 442, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'rmfldpphzi', 'owner_id': 443, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'tsqonorbet', 'owner_id': 444, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'tyumdfmaqp', 'owner_id': 445, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'xsqtlwiosb', 'owner_id': 446, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'mtizbauzih', 'owner_id': 447, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'gcksnplyhp', 'owner_id': 448, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'jmszqisqxz', 'owner_id': 449, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'dyiowsacau', 'owner_id': 450, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'nvskkiwvgv', 'owner_id': 451, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'aepemexapg', 'owner_id': 452, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'kuskrdykbu', 'owner_id': 453, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'vdpybedauj', 'owner_id': 454, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'nnhikkidrm', 'owner_id': 455, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'ujawxbpvez', 'owner_id': 456, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'hrltejjckd', 'owner_id': 457, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'phjociunzp', 'owner_id': 458, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'vrtfbubhbp', 'owner_id': 459, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'pqlwpfftzh', 'owner_id': 460, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'piickiwvqh', 'owner_id': 461, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'wewapqvyqv', 'owner_id': 462, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'yymzkgtizx', 'owner_id': 463, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'jvmiocdxsm', 'owner_id': 464, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'oqklnozqay', 'owner_id': 465, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'dieliuyaui', 'owner_id': 466, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'mkxnlushab', 'owner_id': 467, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'oucvvcadaa', 'owner_id': 468, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'hkugqzuekb', 'owner_id': 469, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'syqciivlkt', 'owner_id': 470, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'nzwtpdgody', 'owner_id': 471, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'asoqqtsylo', 'owner_id': 472, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'xarohcdyol', 'owner_id': 473, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'idrsibhjvz', 'owner_id': 474, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'zuhmthgpez', 'owner_id': 475, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'puavonxjhp', 'owner_id': 476, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'jvxycjjxld', 'owner_id': 477, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'ikmpfkolfd', 'owner_id': 478, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'wdvcsaouvp', 'owner_id': 479, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'bzpdabdmom', 'owner_id': 480, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'jqcwfqqwwu', 'owner_id': 481, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'vbfyahybgc', 'owner_id': 482, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'qmwarntsxe', 'owner_id': 483, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'ivdpwweyvs', 'owner_id': 484, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'xsnhcrfztz', 'owner_id': 485, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'ewlzuahkff', 'owner_id': 486, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'paizczpixz', 'owner_id': 487, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'pwkowhzzmf', 'owner_id': 488, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'uhkgxdvxyd', 'owner_id': 489, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'xhjlkvdmmw', 'owner_id': 490, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'cnvwfhgcwf', 'owner_id': 491, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'lncywcamyy', 'owner_id': 492, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'loofebybsw', 'owner_id': 493, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'dygyzzjwtf', 'owner_id': 494, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'nrgqucdmhi', 'owner_id': 495, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'jdngbmifkn', 'owner_id': 496, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'nqlblylxhl', 'owner_id': 497, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'ldrukjosmt', 'owner_id': 498, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'hhbmebfgsk', 'owner_id': 499, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'ornylragme', 'owner_id': 500, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'frxjqocflx', 'owner_id': 501, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'unmberbwvq', 'owner_id': 502, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'hesdnppjot', 'owner_id': 503, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'pafdntgjln', 'owner_id': 504, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'mahbsuhbzl', 'owner_id': 505, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'mtljphwwoo', 'owner_id': 506, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'xxloseoqtn', 'owner_id': 507, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'xqjipfailt', 'owner_id': 508, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'mdeldldudw', 'owner_id': 509, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'oqgkfcfdkt', 'owner_id': 510, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'xstwqeytkp', 'owner_id': 511, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'cjovwazzsm', 'owner_id': 512, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'wikpakfohd', 'owner_id': 513, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'iqzijuxkjr', 'owner_id': 514, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'tinadlvffm', 'owner_id': 515, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'vjacqqrkgb', 'owner_id': 516, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'zchlpqiaby', 'owner_id': 517, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'idqxgakwwt', 'owner_id': 518, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'cerraeooed', 'owner_id': 519, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'bejoyfxwva', 'owner_id': 520, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'yjfjiqfbmd', 'owner_id': 521, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'evswrlubdt', 'owner_id': 522, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'ihvvszosdm', 'owner_id': 523, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'bgwfeejijv', 'owner_id': 524, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'zabzrxtegy', 'owner_id': 525, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'uaxgdacjqc', 'owner_id': 526, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'yjrfgbslel', 'owner_id': 527, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'rmmmnafoac', 'owner_id': 528, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'mhohlzkbua', 'owner_id': 529, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'nwjanwxnvm', 'owner_id': 530, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'twcmrmyavj', 'owner_id': 531, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'avybimtvua', 'owner_id': 532, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'gelwbrssmj', 'owner_id': 533, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'xavseiayvs', 'owner_id': 534, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'pqrlunzlge', 'owner_id': 535, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'vnakmxsyjo', 'owner_id': 536, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'kgxgzfdasc', 'owner_id': 537, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'zipaodhnrg', 'owner_id': 538, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'jkqidpskfk', 'owner_id': 539, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'tqfkldcdxr', 'owner_id': 540, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'pakvamuotm', 'owner_id': 541, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'zeacicmfmt', 'owner_id': 542, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'aqwwuuuesf', 'owner_id': 543, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'bvlrkjrynl', 'owner_id': 544, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'wqbidzfzbl', 'owner_id': 545, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'ugyrnaaahk', 'owner_id': 546, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'tveleijjix', 'owner_id': 547, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'hsdqumqrnc', 'owner_id': 548, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'amkijxumwa', 'owner_id': 549, 'cats': 5, 'dogs': 0},
#  {'owner_name': 'kmzezxgxpv', 'owner_id': 550, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'cgvavvryuj', 'owner_id': 551, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'nnynwmlkus', 'owner_id': 552, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'cesosgaipp', 'owner_id': 553, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'aqkynbyvgt', 'owner_id': 554, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'axxczqbwsr', 'owner_id': 555, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'dgdpkbchvp', 'owner_id': 556, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'rskkdsctjp', 'owner_id': 557, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'wsjmgsqplg', 'owner_id': 558, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'qhgkdnaxaw', 'owner_id': 559, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'wjnzvnpeak', 'owner_id': 560, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'oazjkxtjen', 'owner_id': 561, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'pizxgiyxnw', 'owner_id': 562, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'kzrgupphey', 'owner_id': 563, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'puhvyemzha', 'owner_id': 564, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'vfspeylmhe', 'owner_id': 565, 'cats': 3, 'dogs': 1},
#  {'owner_name': 'cuavcrkwqb', 'owner_id': 566, 'cats': 0, 'dogs': 0},
#  {'owner_name': 
 'cats': 1, 'dogs': 2},
#  {'owner_name': 'pobgpgvwsp', 'owner_id': 683, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'gmipqsrfej', 'owner_id': 684, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'voyshmknjq', 'owner_id': 685, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'ltfxzwnuwf', 'owner_id': 686, 'cats': 4, 'dogs': 2},
# ...
#  {'owner_name': 'pdgnnepuyb', 'owner_id': 772, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'wugsxeuhdq', 'owner_id': 773, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'agcppnegfr', 'owner_id': 774, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'dzmhbhchke', 'owner_id': 775, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'fqxkfdeaid', 'owner_id': 776, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'klwpcodeic', 'owner_id': 777, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'odkxnsawyu', 'owner_id': 778, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'kenbwbozjb', 'owner_id': 779, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'zxbeyyowbp', 'owner_id': 780, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'bchjuqlimv', 'owner_id': 781, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'ewgycsomqr', 'owner_id': 782, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'zzxscaopip', 'owner_id': 783, 'cats': 3, 'dogs': 4},
#  {'owner_name': 'bqjnaapiet', 'owner_id': 784, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'ptmsbjnxqd', 'owner_id': 785, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'cpwrndwkyy', 'owner_id': 786, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'ucjbmoghhk', 'owner_id': 787, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'wcbeocdtmb', 'owner_id': 788, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'hoxmvtuhnk', 'owner_id': 789, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'lwzvercxau', 'owner_id': 790, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'cpyznipldv', 'owner_id': 791, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'vcatyzijxq', 'owner_id': 792, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'bcexkjzuuf', 'owner_id': 793, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'xyellqfxsn', 'owner_id': 794, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'dfdrzuhrpb', 'owner_id': 795, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'fbmsubyytd', 'owner_id': 796, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'tsslocblbf', 'owner_id': 797, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'ziknsvktca', 'owner_id': 798, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'methittrup', 'owner_id': 799, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'ctsfutxswr', 'owner_id': 800, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'nehnrqbvso', 'owner_id': 801, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'xbosypsujh', 'owner_id': 802, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'furzafkqiz', 'owner_id': 803, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'lwmwjaqzzb', 'owner_id': 804, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'yjxjvlnkeb', 'owner_id': 805, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'dewaxeilzi', 'owner_id': 806, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'vcpsmsaeei', 'owner_id': 807, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'rainpkuxep', 'owner_id': 808, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'ekcvaritho', 'owner_id': 809, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'jgwsrdiddm', 'owner_id': 810, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'mhjersgziv', 'owner_id': 811, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'yexhmtewzt', 'owner_id': 812, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'ffjxzfiiox', 'owner_id': 813, 'cats': 3, 'dogs': 2},
#  {'owner_name': 'fgozfdqnqp', 'owner_id': 814, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'tkgvpvawcn', 'owner_id': 815, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'qtikafslcb', 'owner_id': 816, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'cyzfrnbqgy', 'owner_id': 817, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'zzzxwojqsw', 'owner_id': 818, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'yclrkneeei', 'owner_id': 819, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'mwxvchqxxz', 'owner_id': 820, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'twtnfjybnn', 'owner_id': 821, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'lopxfkwufg', 'owner_id': 822, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'qthlacvrwj', 'owner_id': 823, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'psihiwpiuv', 'owner_id': 824, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'urdptsdfar', 'owner_id': 825, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'iduwiuhnns', 'owner_id': 826, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'foijcxleje', 'owner_id': 827, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'najqqtynks', 'owner_id': 828, 'cats': 3, 'dogs': 0},
#  {'owner_name': 
 'cats': 2, 'dogs': 1},
#  {'owner_name': 'weetcbscim', 'owner_id': 883, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'zgabgoruqc', 'owner_id': 884, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'jvkdnqcivf', 'owner_id': 885, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'yayiqdetdm', 'owner_id': 886, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'fltzjrudtf', 'owner_id': 887, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'davtpjmvpd', 'owner_id': 888, 'cats': 2, 'dogs': 2},
#  {'owner_name': 'lrdyotzytp', 'owner_id': 889, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'imiipwrieh', 'owner_id': 890, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'dylmtmagos', 'owner_id': 891, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'kagueikcat', 'owner_id': 892, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'bweioshthb', 'owner_id': 893, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'igkpalombr', 'owner_id': 894, 'cats': 4, 'dogs': 5},
#  {'owner_name': 'ylwnpujqox', 'owner_id': 895, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'ekrhsssdop', 'owner_id': 896, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'uupuqvygew', 'owner_id': 897, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'fbtaavocdh', 'owner_id': 898, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'qiuuhgrheq', 'owner_id': 899, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'kfnzlzhysl', 'owner_id': 900, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'icfllayooe', 'owner_id': 901, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'qfldaqwrwx', 'owner_id': 902, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'ybdluaycdt', 'owner_id': 903, 'cats': 1, 'dogs': 4},
#  {'owner_name': 'lmekmuyzzr', 'owner_id': 904, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'egdewvgkko', 'owner_id': 905, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'elpnkqntqq', 'owner_id': 906, 'cats': 1, 'dogs': 3},
#  {'owner_name': 'jnixfbvrlm', 'owner_id': 907, 'cats': 1, 'dogs': 1},
#  {'owner_name': 'zybgobrtov', 'owner_id': 908, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'etqgorngtr', 'owner_id': 909, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'hhdqbxnoeh', 'owner_id': 910, 'cats': 4, 'dogs': 3},
#  {'owner_name': 'ccwuyckzlr', 'owner_id': 911, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'tvbxuskwdu', 'owner_id': 912, 'cats': 1, 'dogs': 0},
#  {'owner_name': 'gbchexqihb', 'owner_id': 913, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'gowinbaykb', 'owner_id': 914, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'snfpvqjumc', 'owner_id': 915, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'bclfdwgxwy', 'owner_id': 916, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'gyxgighskj', 'owner_id': 917, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'dqvumojkbk', 'owner_id': 918, 'cats': 3, 'dogs': 5},
#  {'owner_name': 'rjoshmerhb', 'owner_id': 919, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'smhftmddut', 'owner_id': 920, 'cats': 1, 'dogs': 2},
#  {'owner_name': 'yqnxkltgvm', 'owner_id': 921, 'cats': 4, 'dogs': 4},
#  {'owner_name': 'huqcggkzfw', 'owner_id': 922, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'vhjoanfsxv', 'owner_id': 923, 'cats': 0, 'dogs': 4},
#  {'owner_name': 'eothmfqdyi', 'owner_id': 924, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'uiakthecau', 'owner_id': 925, 'cats': 0, 'dogs': 5},
#  {'owner_name': 'rwbekdnczb', 'owner_id': 926, 'cats': 5, 'dogs': 5},
#  {'owner_name': 'uybzyrlltb', 'owner_id': 927, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'edkvmicdmi', 'owner_id': 928, 'cats': 5, 'dogs': 3},
#  {'owner_name': 'zsankewonz', 'owner_id': 929, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'srhgetcspm', 'owner_id': 930, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'sgnrjlmfzk', 'owner_id': 931, 'cats': 3, 'dogs': 0},
#  {'owner_name': 'wwtizworjm', 'owner_id': 932, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'hbxgwsdjvo', 'owner_id': 933, 'cats': 3, 'dogs': 3},
#  {'owner_name': 'xchtffmgbd', 'owner_id': 934, 'cats': 2, 'dogs': 4},
#  {'owner_name': 'imbgrcwpkw', 'owner_id': 935, 'cats': 4, 'dogs': 2},
#  {'owner_name': 'mmsbkrgatv', 'owner_id': 936, 'cats': 1, 'dogs': 1},
#  {'owner_name': 
 'cats': 1, 'dogs': 5},
#  {'owner_name': 'lzfbemibbu', 'owner_id': 984, 'cats': 2, 'dogs': 1},
#  {'owner_name': 'webzfwlduj', 'owner_id': 985, 'cats': 5, 'dogs': 4},
#  {'owner_name': 'ssoylhjwpk', 'owner_id': 986, 'cats': 0, 'dogs': 2},
#  {'owner_name': 'vkjyyjtgng', 'owner_id': 987, 'cats': 0, 'dogs': 3},
#  {'owner_name': 'ffmljcbhin', 'owner_id': 988, 'cats': 0, 'dogs': 1},
#  {'owner_name': 'mvqgpemuuy', 'owner_id': 989, 'cats': 5, 'dogs': 2},
#  {'owner_name': 'ttxonspmoj', 'owner_id': 990, 'cats': 4, 'dogs': 0},
#  {'owner_name': 'wigtwruhxt', 'owner_id': 991, 'cats': 0, 'dogs': 0},
#  {'owner_name': 'eyizgxhrov', 'owner_id': 992, 'cats': 2, 'dogs': 0},
#  {'owner_name': 'yvzpglmocn', 'owner_id': 993, 'cats': 2, 'dogs': 3},
#  {'owner_name': 'wkuvshmbpk', 'owner_id': 994, 'cats': 5, 'dogs': 1},
#  {'owner_name': 'sklwriknwn', 'owner_id': 995, 'cats': 1, 'dogs': 5},
#  {'owner_name': 'ayetwfgyad', 'owner_id': 996, 'cats': 2, 'dogs': 5},
#  {'owner_name': 'lwkozsjzld', 'owner_id': 997, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'jfxnmcrqyz', 'owner_id': 998, 'cats': 4, 'dogs': 1},
#  {'owner_name': 'gysrvzvbmt', 'owner_id': 999, 'cats': 2, 'dogs': 5}]

# %%
upload_res = es_mgr.create_document(collection_name = "meow", documents=rand_data)
# Out:
# List of faulty documents: []
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
upload_res
# Out:
# {'response': '200',
#  'ids': ['YTy8E4UBimE7927zEki1',
#   'Yjy8E4UBimE7927zEki1',
#   'Yzy8E4UBimE7927zEki1',
#   'ZDy8E4UBimE7927zEki1',
#   'ZTy8E4UBimE7927zEki1',
#   'Zjy8E4UBimE7927zEki1',
#   'Zzy8E4UBimE7927zEki1',
#   'aDy8E4UBimE7927zEki1',
#   'aTy8E4UBimE7927zEki1',
#   'ajy8E4UBimE7927zEki1',
#   'azy8E4UBimE7927zEki1',
#   'bDy8E4UBimE7927zEki1',
#   'bTy8E4UBimE7927zEki1',
#   'bjy8E4UBimE7927zEki1',
#   'bzy8E4UBimE7927zEki1',
#   'cDy8E4UBimE7927zEki1',
#   'cTy8E4UBimE7927zEki1',
#   'cjy8E4UBimE7927zEki1',
#   'czy8E4UBimE7927zEki1',
#   'dDy8E4UBimE7927zEki1',
#   'dTy8E4UBimE7927zEki1',
#   'djy8E4UBimE7927zEki1',
#   'dzy8E4UBimE7927zEki1',
#   'eDy8E4UBimE7927zEki1',
#   'eTy8E4UBimE7927zEki1',
#   'ejy8E4UBimE7927zEki1',
#   'ezy8E4UBimE7927zEki1',
#   'fDy8E4UBimE7927zEki1',
#   'fTy8E4UBimE7927zEki1',
#   'fjy8E4UBimE7927zEki1',
#   'yTy8E4UBimE7927zEki2',
#   'yjy8E4UBimE7927zEki2',
#   'yzy8E4UBimE7927zEki2',
#   'zDy8E4UBimE7927zEki2',
#   'zTy8E4UBimE7927zEki2',
#   'zjy8E4UBimE7927zEki2',
#   'zzy8E4UBimE7927zEki2',
#   '0Dy8E4UBimE7927zEki2',
#   '0Ty8E4UBimE7927zEki2',
#   '0jy8E4UBimE7927zEki2',
#   '0zy8E4UBimE7927zEki2',
#   '1Dy8E4UBimE7927zEki2',
#   '1Ty8E4UBimE7927zEki2',
#   '1jy8E4UBimE7927zEki2',
#   '1zy8E4UBimE7927zEki2',
#   '2Dy8E4UBimE7927zEki2',
#   '2Ty8E4UBimE7927zEki2',
#   '2jy8E4UBimE7927zEki2',
#   '2zy8E4UBimE7927zEki2',
#   '3Dy8E4UBimE7927zEki2',
#   '3Ty8E4UBimE7927zEki2',
#   '3jy8E4UBimE7927zEki2',
#   '3zy8E4UBimE7927zEki2',
#   '4Dy8E4UBimE7927zEki2',
#   '4Ty8E4UBimE7927zEki2',
#   '4jy8E4UBimE7927zEki2',
#   '4zy8E4UBimE7927zEki2',
#   '5Dy8E4UBimE7927zEki2',
#   '5Ty8E4UBimE7927zEki2',
#   '5jy8E4UBimE7927zEki2',
#   '5zy8E4UBimE7927zEki2',
#   '6Dy8E4UBimE7927zEki2',
#   '6Ty8E4UBimE7927zEki2',
#   '6jy8E4UBimE7927zEki2',
#   '6zy8E4UBimE7927zEki2',
#   '7Dy8E4UBimE7927zEki2',
#   '7Ty8E4UBimE7927zEki2',
#   '7jy8E4UBimE7927zEki2',
#   '7zy8E4UBimE7927zEki2',
#   '8Dy8E4UBimE7927zEki2',
#   '8Ty8E4UBimE7927zEki2',
#   '8jy8E4UBimE7927zEki2',
#   '8zy8E4UBimE7927zEki2',
#   '9Dy8E4UBimE7927zEki2',
#   '9Ty8E4UBimE7927zEki2',
#   '9jy8E4UBimE7927zEki2',
#   '9zy8E4UBimE7927zEki2',
#   '-Dy8E4UBimE7927zEki2',
#   '-Ty8E4UBimE7927zEki2',
#   '-jy8E4UBimE7927zEki2',
#   '-zy8E4UBimE7927zEki2',
#   '_Dy8E4UBimE7927zEki2',
#   '_Ty8E4UBimE7927zEki2',
#   '_jy8E4UBimE7927zEki2',
#   '_zy8E4UBimE7927zEki2',
#   'ADy8E4UBimE7927zEkm2',
#   'ATy8E4UBimE7927zEkm2',
#   'Ajy8E4UBimE7927zEkm2',
#   'Azy8E4UBimE7927zEkm2',
#   'BDy8E4UBimE7927zEkm2',
#   'BTy8E4UBimE7927zEkm2',
#   'Bjy8E4UBimE7927zEkm2',
#   'Bzy8E4UBimE7927zEkm2',
#   'CDy8E4UBimE7927zEkm2',
#   'CTy8E4UBimE7927zEkm2',
#   'Cjy8E4UBimE7927zEkm2',
#   'Czy8E4UBimE7927zEkm2',
#   'DDy8E4UBimE7927zEkm2',
#   'DTy8E4UBimE7927zEkm2',
#   'Djy8E4UBimE7927zEkm2',
#   'Dzy8E4UBimE7927zEkm2',
#   'EDy8E4UBimE7927zEkm2',
#   'ETy8E4UBimE7927zEkm2',
#   'Ejy8E4UBimE7927zEkm2',
#   'Ezy8E4UBimE7927zEkm2',
#   'FDy8E4UBimE7927zEkm2',
#   'FTy8E4UBimE7927zEkm2',
#   'Fjy8E4UBimE7927zEkm2',
#   'Fzy8E4UBimE7927zEkm2',
#   'GDy8E4UBimE7927zEkm2',
#   'GTy8E4UBimE7927zEkm2',
#   'Gjy8E4UBimE7927zEkm2',
#   'Gzy8E4UBimE7927zEkm2',
#   'HDy8E4UBimE7927zEkm2',
#   'HTy8E4UBimE7927zEkm2',
#   'Hjy8E4UBimE7927zEkm2',
#   'Hzy8E4UBimE7927zEkm2',
#   'IDy8E4UBimE7927zEkm2',
#   'ITy8E4UBimE7927zEkm2',
#   'Ijy8E4UBimE7927zEkm2',
#   'Izy8E4UBimE7927zEkm2',
#   'JDy8E4UBimE7927zEkm2',
#   'JTy8E4UBimE7927zEkm2',
#   'Jjy8E4UBimE7927zEkm2',
#   'Jzy8E4UBimE7927zEkm2',
#   'KDy8E4UBimE7927zEkm2',
#   'KTy8E4UBimE7927zEkm2',
#   'Kjy8E4UBimE7927zEkm2',
#   'Kzy8E4UBimE7927zEkm2',
#   'LDy8E4UBimE7927zEkm2',
#   'LTy8E4UBimE7927zEkm2',
#   'Ljy8E4UBimE7927zEkm2',
#   'Lzy8E4UBimE7927zEkm2',
#   'MDy8E4UBimE7927zEkm2',
#   'MTy8E4UBimE7927zEkm2',
#   'Mjy8E4UBimE7927zEkm2',
#   'Mzy8E4UBimE7927zEkm2',
#   'NDy8E4UBimE7927zEkm2',
#   'NTy8E4UBimE7927zEkm2',
#   'Njy8E4UBimE7927zEkm2',
#   'Nzy8E4UBimE7927zEkm2',
#   'ODy8E4UBimE7927zEkm2',
#   'OTy8E4UBimE7927zEkm2',
#   'Ojy8E4UBimE7927zEkm2',
#   'Ozy8E4UBimE7927zEkm2',
#   'PDy8E4UBimE7927zEkm2',
#   'PTy8E4UBimE7927zEkm2',
#   'Pjy8E4UBimE7927zEkm2',
#   'Pzy8E4UBimE7927zEkm2',
#   'QDy8E4UBimE7927zEkm2',
#   'QTy8E4UBimE7927zEkm2',
#   'Qjy8E4UBimE7927zEkm2',
#   'Qzy8E4UBimE7927zEkm2',
#   'RDy8E4UBimE7927zEkm2',
#   'RTy8E4UBimE7927zEkm2',
#   'Rjy8E4UBimE7927zEkm2',
#   'Rzy8E4UBimE7927zEkm2',
#   'SDy8E4UBimE7927zEkm2',
#   'STy8E4UBimE7927zEkm2',
#   'Sjy8E4UBimE7927zEkm2',
#   'Szy8E4UBimE7927zEkm2',
#   'TDy8E4UBimE7927zEkm2',
#   'TTy8E4UBimE7927zEkm2',
#   'Tjy8E4UBimE7927zEkm2',
#   'Tzy8E4UBimE7927zEkm2',
#   'UDy8E4UBimE7927zEkm2',
#   'UTy8E4UBimE7927zEkm2',
#   'Ujy8E4UBimE7927zEkm2',
#   'Uzy8E4UBimE7927zEkm2',
#   'VDy8E4UBimE7927zEkm2',
#   'VTy8E4UBimE7927zEkm2',
#   'Vjy8E4UBimE7927zEkm2',
#   'Vzy8E4UBimE7927zEkm2',
#   'WDy8E4UBimE7927zEkm2',
#   'WTy8E4UBimE7927zEkm2',
#   'Wjy8E4UBimE7927zEkm2',
#   'Wzy8E4UBimE7927zEkm2',
#   'XDy8E4UBimE7927zEkm2',
#   'XTy8E4UBimE7927zEkm2',
#   'Xjy8E4UBimE7927zEkm2',
#   'Xzy8E4UBimE7927zEkm2',
#   'YDy8E4UBimE7927zEkm2',
#   'YTy8E4UBimE7927zEkm2',
#   'Yjy8E4UBimE7927zEkm2',
#   'Yzy8E4UBimE7927zEkm2',
#   'ZDy8E4UBimE7927zEkm2',
#   'ZTy8E4UBimE7927zEkm2',
#   'Zjy8E4UBimE7927zEkm2',
#   'Zzy8E4UBimE7927zEkm2',
#   'aDy8E4UBimE7927zEkm2',
#   'aTy8E4UBimE7927zEkm2',
#   'ajy8E4UBimE7927zEkm2',
#   'azy8E4UBimE7927zEkm2',
#   'bDy8E4UBimE7927zEkm2',
#   'bTy8E4UBimE7927zEkm2',
#   'bjy8E4UBimE7927zEkm2',
#   'bzy8E4UBimE7927zEkm2',
#   'cDy8E4UBimE7927zEkm2',
#   'cTy8E4UBimE7927zEkm2',
#   'cjy8E4UBimE7927zEkm2',
#   'czy8E4UBimE7927zEkm2',
#   'dDy8E4UBimE7927zEkm2',
#   'dTy8E4UBimE7927zEkm2',
#   'djy8E4UBimE7927zEkm2',
#   'dzy8E4UBimE7927zEkm2',
#   'eDy8E4UBimE7927zEkm2',
#   'eTy8E4UBimE7927zEkm2',
#   'ejy8E4UBimE7927zEkm2',
#   'ezy8E4UBimE7927zEkm2',
#   'fDy8E4UBimE7927zEkm2',
#   'fTy8E4UBimE7927zEkm2',
#   'fjy8E4UBimE7927zEkm2',
#   'fzy8E4UBimE7927zEkm2',
#   'gDy8E4UBimE7927zEkm2',
#   'gTy8E4UBimE7927zEkm2',
#   'gjy8E4UBimE7927zEkm2',
#   'gzy8E4UBimE7927zEkm2',
#   'hDy8E4UBimE7927zEkm2',
#   'hTy8E4UBimE7927zEkm2',
#   'hjy8E4UBimE7927zEkm2',
#   'hzy8E4UBimE7927zEkm2',
#   'iDy8E4UBimE7927zEkm2',
#   'iTy8E4UBimE7927zEkm2',
#   'ijy8E4UBimE7927zEkm2',
#   'izy8E4UBimE7927zEkm2',
#   'jDy8E4UBimE7927zEkm2',
#   'jTy8E4UBimE7927zEkm2',
#   'jjy8E4UBimE7927zEkm2',
#   'jzy8E4UBimE7927zEkm2',
#   'kDy8E4UBimE7927zEkm2',
#   'kTy8E4UBimE7927zEkm2',
#   'kjy8E4UBimE7927zEkm2',
#   'kzy8E4UBimE7927zEkm2',
#   'lDy8E4UBimE7927zEkm2',
#   'lTy8E4UBimE7927zEkm2',
#   'ljy8E4UBimE7927zEkm2',
#   'lzy8E4UBimE7927zEkm2',
#   'mDy8E4UBimE7927zEkm2',
#   'mTy8E4UBimE7927zEkm2',
#   'mjy8E4UBimE7927zEkm2',
#   'mzy8E4UBimE7927zEkm2',
#   'nDy8E4UBimE7927zEkm2',
#   'nTy8E4UBimE7927zEkm2',
#   'njy8E4UBimE7927zEkm2',
#   'nzy8E4UBimE7927zEkm2',
#   'oDy8E4UBimE7927zEkm2',
#   'oTy8E4UBimE7927zEkm2',
#   'ojy8E4UBimE7927zEkm2',
#   'ozy8E4UBimE7927zEkm2',
#   'pDy8E4UBimE7927zEkm2',
#   'pTy8E4UBimE7927zEkm2',
#   'pjy8E4UBimE7927zEkm2',
#   'pzy8E4UBimE7927zEkm2',
#   'qDy8E4UBimE7927zEkm2',
#   'qTy8E4UBimE7927zEkm2',
#   'qjy8E4UBimE7927zEkm2',
#   'qzy8E4UBimE7927zEkm2',
#   'rDy8E4UBimE7927zEkm2',
#   'rTy8E4UBimE7927zEkm2',
#   'rjy8E4UBimE7927zEkm2',
#   'rzy8E4UBimE7927zEkm2',
#   'sDy8E4UBimE7927zEkm2',
#   'sTy8E4UBimE7927zEkm2',
#   'sjy8E4UBimE7927zEkm2',
#   'szy8E4UBimE7927zEkm2',
#   'tDy8E4UBimE7927zEkm2',
#   'tTy8E4UBimE7927zEkm2',
#   'tjy8E4UBimE7927zEkm2',
#   'tzy8E4UBimE7927zEkm2',
#   'uDy8E4UBimE7927zEkm2',
#   'uTy8E4UBimE7927zEkm2',
#   'ujy8E4UBimE7927zEkm2',
#   'uzy8E4UBimE7927zEkm2',
#   'vDy8E4UBimE7927zEkm2',
#   'vTy8E4UBimE7927zEkm2',
#   'vjy8E4UBimE7927zEkm2',
#   'vzy8E4UBimE7927zEkm2',
#   'wDy8E4UBimE7927zEkm2',
#   'wTy8E4UBimE7927zEkm2',
#   'wjy8E4UBimE7927zEkm2',
#   'wzy8E4UBimE7927zEkm2',
#   'xDy8E4UBimE7927zEkm2',
#   'xTy8E4UBimE7927zEkm2',
#   'xjy8E4UBimE7927zEkm2',
#   'xzy8E4UBimE7927zEkm2',
#   'yDy8E4UBimE7927zEkm2',
#   'yTy8E4UBimE7927zEkm2',
#   'yjy8E4UBimE7927zEkm2',
#   'yzy8E4UBimE7927zEkm2',
#   'zDy8E4UBimE7927zEkm2',
#   'zTy8E4UBimE7927zEkm2',
#   'zjy8E4UBimE7927zEkm2',
#   'zzy8E4UBimE7927zEkm2',
#   '0Dy8E4UBimE7927zEkm2',
#   '0Ty8E4UBimE7927zEkm2',
#   '0jy8E4UBimE7927zEkm2',
#   '0zy8E4UBimE7927zEkm2',
#   '1Dy8E4UBimE7927zEkm2',
#   '1Ty8E4UBimE7927zEkm2',
#   '1jy8E4UBimE7927zEkm2',
#   '1zy8E4UBimE7927zEkm2',
#   '2Dy8E4UBimE7927zEkm2',
#   '2Ty8E4UBimE7927zEkm2',
#   '2jy8E4UBimE7927zEkm2',
#   '2zy8E4UBimE7927zEkm2',
#   '3Dy8E4UBimE7927zEkm2',
#   '3Ty8E4UBimE7927zEkm2',
#   '3jy8E4UBimE7927zEkm2',
#   '3zy8E4UBimE7927zEkm2',
#   '4Dy8E4UBimE7927zEkm2',
#   '4Ty8E4UBimE7927zEkm2',
#   '4jy8E4UBimE7927zEkm2',
#   '4zy8E4UBimE7927zEkm2',
#   '5Dy8E4UBimE7927zEkm2',
#   '5Ty8E4UBimE7927zEkm2',
#   '5jy8E4UBimE7927zEkm2',
#   '5zy8E4UBimE7927zEkm2',
#   '6Dy8E4UBimE7927zEkm2',
#   '6Ty8E4UBimE7927zEkm2',
#   '6jy8E4UBimE7927zEkm2',
#   '6zy8E4UBimE7927zEkm2',
#   '7Dy8E4UBimE7927zEkm2',
#   '7Ty8E4UBimE7927zEkm2',
#   '7jy8E4UBimE7927zEkm2',
#   '7zy8E4UBimE7927zEkm2',
#   '8Dy8E4UBimE7927zEkm2',
#   '8Ty8E4UBimE7927zEkm2',
#   '8jy8E4UBimE7927zEkm2',
#   '8zy8E4UBimE7927zEkm2',
#   '9Dy8E4UBimE7927zEkm2',
#   '9Ty8E4UBimE7927zEkm2',
#   '9jy8E4UBimE7927zEkm2',
#   '9zy8E4UBimE7927zEkm2',
#   '-Dy8E4UBimE7927zEkm2',
#   '-Ty8E4UBimE7927zEkm2',
#   '-jy8E4UBimE7927zEkm2',
#   '-zy8E4UBimE7927zEkm2',
#   '_Dy8E4UBimE7927zEkm2',
#   '_Ty8E4UBimE7927zEkm2',
#   '_jy8E4UBimE7927zEkm2',
#   '_zy8E4UBimE7927zEkm2',
#   'ADy8E4UBimE7927zEkq2',
#   'ATy8E4UBimE7927zEkq2',
#   'Ajy8E4UBimE7927zEkq2',
#   'Azy8E4UBimE7927zEkq2',
#   'BDy8E4UBimE7927zEkq2',
#   'BTy8E4UBimE7927zEkq2',
#   'Bjy8E4UBimE7927zEkq2',
#   'Bzy8E4UBimE7927zEkq2',
#   'CDy8E4UBimE7927zEkq2',
#   'CTy8E4UBimE7927zEkq2',
#   'Cjy8E4UBimE7927zEkq2',
#   'Czy8E4UBimE7927zEkq2',
#   'DDy8E4UBimE7927zEkq2',
#   'DTy8E4UBimE7927zEkq2',
#   'Djy8E4UBimE7927zEkq2',
#   'Dzy8E4UBimE7927zEkq2',
#   'EDy8E4UBimE7927zEkq2',
#   'ETy8E4UBimE7927zEkq2',
#   'Ejy8E4UBimE7927zEkq2',
#   'Ezy8E4UBimE7927zEkq2',
#   'FDy8E4UBimE7927zEkq2',
#   'FTy8E4UBimE7927zEkq2',
#   'Fjy8E4UBimE7927zEkq2',
#   'Fzy8E4UBimE7927zEkq2',
#   'GDy8E4UBimE7927zEkq2',
#   'GTy8E4UBimE7927zEkq2',
#   'Gjy8E4UBimE7927zEkq2',
#   'Gzy8E4UBimE7927zEkq2',
#   'HDy8E4UBimE7927zEkq2',
#   'HTy8E4UBimE7927zEkq2',
#   'Hjy8E4UBimE7927zEkq2',
#   'Hzy8E4UBimE7927zEkq2',
#   'IDy8E4UBimE7927zEkq2',
#   'ITy8E4UBimE7927zEkq2',
#   'Ijy8E4UBimE7927zEkq2',
#   'Izy8E4UBimE7927zEkq2',
#   'JDy8E4UBimE7927zEkq2',
#   'JTy8E4UBimE7927zEkq2',
#   'Jjy8E4UBimE7927zEkq2',
#   'Jzy8E4UBimE7927zEkq2',
#   'KDy8E4UBimE7927zEkq2',
#   'KTy8E4UBimE7927zEkq2',
#   'Kjy8E4UBimE7927zEkq2',
#   'Kzy8E4UBimE7927zEkq2',
#   'LDy8E4UBimE7927zEkq2',
#   'LTy8E4UBimE7927zEkq2',
#   'Ljy8E4UBimE7927zEkq2',
#   'Lzy8E4UBimE7927zEkq2',
#   'MDy8E4UBimE7927zEkq2',
#   'MTy8E4UBimE7927zEkq2',
#   'Mjy8E4UBimE7927zEkq2',
#   'Mzy8E4UBimE7927zEkq2',
#   'NDy8E4UBimE7927zEkq2',
#   'NTy8E4UBimE7927zEkq2',
#   'Njy8E4UBimE7927zEkq2',
#   'Nzy8E4UBimE7927zEkq2',
#   'ODy8E4UBimE7927zEkq2',
#   'OTy8E4UBimE7927zEkq2',
#   'Ojy8E4UBimE7927zEkq2',
#   'Ozy8E4UBimE7927zEkq2',
#   'PDy8E4UBimE7927zEkq2',
#   'PTy8E4UBimE7927zEkq2',
#   'Pjy8E4UBimE7927zEkq2',
#   'Pzy8E4UBimE7927zEkq2',
#   'QDy8E4UBimE7927zEkq2',
#   'QTy8E4UBimE7927zEkq2',
#   'Qjy8E4UBimE7927zEkq2',
#   'Qzy8E4UBimE7927zEkq2',
#   'RDy8E4UBimE7927zEkq2',
#   'RTy8E4UBimE7927zEkq2',
#   'Rjy8E4UBimE7927zEkq2',
#   'Rzy8E4UBimE7927zEkq2',
#   'SDy8E4UBimE7927zEkq2',
#   'STy8E4UBimE7927zEkq2',
#   'Sjy8E4UBimE7927zEkq2',
#   'Szy8E4UBimE7927zEkq2',
#   'TDy8E4UBimE7927zEkq2',
#   'TTy8E4UBimE7927zEkq2',
#   'Tjy8E4UBimE7927zEkq2',
#   'Tzy8E4UBimE7927zEkq2',
#   'UDy8E4UBimE7927zEkq2',
#   'UTy8E4UBimE7927zEkq2',
#   'Ujy8E4UBimE7927zEkq2',
#   'Uzy8E4UBimE7927zEkq2',
#   'VDy8E4UBimE7927zEkq2',
#   'VTy8E4UBimE7927zEkrg',
#   'Vjy8E4UBimE7927zEkrg',
#   'Vzy8E4UBimE7927zEkrg',
#   'WDy8E4UBimE7927zEkrg',
#   'WTy8E4UBimE7927zEkrg',
#   'Wjy8E4UBimE7927zEkrg',
#   'Wzy8E4UBimE7927zEkrg',
#   'XDy8E4UBimE7927zEkrg',
#   'XTy8E4UBimE7927zEkrg',
#   'Xjy8E4UBimE7927zEkrg',
#   'Xzy8E4UBimE7927zEkrg',
#   'YDy8E4UBimE7927zEkrg',
#   'YTy8E4UBimE7927zEkrg',
#   'Yjy8E4UBimE7927zEkrg',
#   'Yzy8E4UBimE7927zEkrg',
#   'ZDy8E4UBimE7927zEkrg',
#   'ZTy8E4UBimE7927zEkrg',
#   'Zjy8E4UBimE7927zEkrg',
#   'Zzy8E4UBimE7927zEkrg',
#   'aDy8E4UBimE7927zEkrg',
#   'aTy8E4UBimE7927zEkrg',
#   'ajy8E4UBimE7927zEkrg',
#   '9zy8E4UBimE7927zEkrg',
#   '-Dy8E4UBimE7927zEkrg',
#   '-Ty8E4UBimE7927zEkrg',
#   '-jy8E4UBimE7927zEkrg',
#   '-zy8E4UBimE7927zEkrg',
#   '_Dy8E4UBimE7927zEkrg',
#   '_Ty8E4UBimE7927zEkrg',
#   '_jy8E4UBimE7927zEkrg',
#   '_zy8E4UBimE7927zEkrg',
#   'ADy8E4UBimE7927zEkvg',
#   'ATy8E4UBimE7927zEkvg',
#   'Ajy8E4UBimE7927zEkvg',
#   'Azy8E4UBimE7927zEkvg',
#   'BDy8E4UBimE7927zEkvg',
#   'BTy8E4UBimE7927zEkvg',
#   'Bjy8E4UBimE7927zEkvg',
#   'Bzy8E4UBimE7927zEkvg',
#   'CDy8E4UBimE7927zEkvg',
#   'CTy8E4UBimE7927zEkvg',
#   'Cjy8E4UBimE7927zEkvg',
#   'Czy8E4UBimE7927zEkvg',
#   'DDy8E4UBimE7927zEkvg',
#   'DTy8E4UBimE7927zEkvg',
#   'Djy8E4UBimE7927zEkvg',
#   'Dzy8E4UBimE7927zEkvg',
#   'EDy8E4UBimE7927zEkvg',
#   'ETy8E4UBimE7927zEkvg',
#   'Ejy8E4UBimE7927zEkvg',
#   'Ezy8E4UBimE7927zEkvg',
#   'FDy8E4UBimE7927zEkvg',
#   'FTy8E4UBimE7927zEkvg',
#   'Fjy8E4UBimE7927zEkvg',
#   'Fzy8E4UBimE7927zEkvg',
#   'GDy8E4UBimE7927zEkvg',
#   'GTy8E4UBimE7927zEkvg',
#   'Gjy8E4UBimE7927zEkvg',
#   'Gzy8E4UBimE7927zEkvg',
#   'HDy8E4UBimE7927zEkvg',
#   'HTy8E4UBimE7927zEkvg',
#   'Hjy8E4UBimE7927zEkvg',
#   'Hzy8E4UBimE7927zEkvg',
#   'IDy8E4UBimE7927zEkvg',
#   'ITy8E4UBimE7927zEkvg',
#   'Ijy8E4UBimE7927zEkvg',
#   'Izy8E4UBimE7927zEkvg',
#   'JDy8E4UBimE7927zEkvg',
#   'JTy8E4UBimE7927zEkvg',
#   'Jjy8E4UBimE7927zEkvg',
#   'Jzy8E4UBimE7927zEkvg',
#   'KDy8E4UBimE7927zEkvg',
#   'KTy8E4UBimE7927zEkvg',
#   'Kjy8E4UBimE7927zEkvg',
#   'Kzy8E4UBimE7927zEkvg',
#   'LDy8E4UBimE7927zEkvg',
#   'LTy8E4UBimE7927zEkvg',
#   'Ljy8E4UBimE7927zEkvg',
#   'Lzy8E4UBimE7927zEkvg',
#   'MDy8E4UBimE7927zEkvg',
#   'MTy8E4UBimE7927zEkvg',
#   'Mjy8E4UBimE7927zEkvg',
#   'Mzy8E4UBimE7927zEkvg',
#   'NDy8E4UBimE7927zEkvg',
#   'NTy8E4UBimE7927zEkvg',
#   'Njy8E4UBimE7927zEkvg',
#   'Nzy8E4UBimE7927zEkvg',
#   'ODy8E4UBimE7927zEkvg',
#   'OTy8E4UBimE7927zEkvg',
#   'Ojy8E4UBimE7927zEkvg',
#   'Ozy8E4UBimE7927zEkvg',
#   'PDy8E4UBimE7927zEkvg',
#   'PTy8E4UBimE7927zEkvg',
#   'Pjy8E4UBimE7927zEkvg',
#   'Pzy8E4UBimE7927zEkvg',
#   'QDy8E4UBimE7927zEkvg',
#   'QTy8E4UBimE7927zEkvg',
#   'Qjy8E4UBimE7927zEkvg',
#   'Qzy8E4UBimE7927zEkvg',
#   'RDy8E4UBimE7927zEkvg',
#   'RTy8E4UBimE7927zEkvg',
#   'Rjy8E4UBimE7927zEkvg',
#   'Rzy8E4UBimE7927zEkvg',
#   'SDy8E4UBimE7927zEkvg',
#   'STy8E4UBimE7927zEkvg',
#   'Sjy8E4UBimE7927zEkvg',
#   'Szy8E4UBimE7927zEkvg',
#   'TDy8E4UBimE7927zEkvg',
#   'TTy8E4UBimE7927zEkvg',
#   'Tjy8E4UBimE7927zEkvg',
#   'Tzy8E4UBimE7927zEkvg',
#   'UDy8E4UBimE7927zEkvg',
#   'UTy8E4UBimE7927zEkvg',
#   'Ujy8E4UBimE7927zEkvg',
#   'Uzy8E4UBimE7927zEkvg',
#   'VDy8E4UBimE7927zEkvg',
#   'VTy8E4UBimE7927zEkvg',
#   'Vjy8E4UBimE7927zEkvg',
#   'Vzy8E4UBimE7927zEkvg',
#   'WDy8E4UBimE7927zEkvg',
#   'WTy8E4UBimE7927zEkvg',
#   'Wjy8E4UBimE7927zEkvg',
#   'Wzy8E4UBimE7927zEkvg',
#   'XDy8E4UBimE7927zEkvg',
#   'XTy8E4UBimE7927zEkvg',
#   'Xjy8E4UBimE7927zEkvg',
#   'Xzy8E4UBimE7927zEkvg',
#   'YDy8E4UBimE7927zEkvg',
#   'YTy8E4UBimE7927zEkvg',
#   'Yjy8E4UBimE7927zEkvg',
#   'Yzy8E4UBimE7927zEkvg',
#   'ZDy8E4UBimE7927zEkvg',
#   'ZTy8E4UBimE7927zEkvg',
#   'Zjy8E4UBimE7927zEkvg',
#   'Zzy8E4UBimE7927zEkvg',
#   'aDy8E4UBimE7927zEkvg',
#   'aTy8E4UBimE7927zEkvg',
#   'ajy8E4UBimE7927zEkvg',
#   'azy8E4UBimE7927zEkvg',
#   'bDy8E4UBimE7927zEkvg',
#   'bTy8E4UBimE7927zEkvg',
#   'bjy8E4UBimE7927zEkvg',
#   'bzy8E4UBimE7927zEkvg',
#   'cDy8E4UBimE7927zEkvg',
#   'cTy8E4UBimE7927zEkvg',
#   'cjy8E4UBimE7927zEkvg',
#   'czy8E4UBimE7927zEkvg',
#   'dDy8E4UBimE7927zEkvg',
#   'dTy8E4UBimE7927zEkvg',
#   'djy8E4UBimE7927zEkvg',
#   'dzy8E4UBimE7927zEkvg',
#   'eDy8E4UBimE7927zEkvg',
#   'eTy8E4UBimE7927zEkvg',
#   'ejy8E4UBimE7927zEkvg',
#   'ezy8E4UBimE7927zEkvg',
#   'fDy8E4UBimE7927zEkvg',
#   'fTy8E4UBimE7927zEkvg',
#   'fjy8E4UBimE7927zEkvg',
#   'fzy8E4UBimE7927zEkvg',
#   'gDy8E4UBimE7927zEkvg',
#   'gTy8E4UBimE7927zEkvg',
#   'gjy8E4UBimE7927zEkvg',
#   'gzy8E4UBimE7927zEkvg',
#   'hDy8E4UBimE7927zEkvg',
#   'hTy8E4UBimE7927zEkvg',
#   'hjy8E4UBimE7927zEkvg',
#   'hzy8E4UBimE7927zEkvg',
#   'iDy8E4UBimE7927zEkvg',
#   'iTy8E4UBimE7927zEkvg',
#   'ijy8E4UBimE7927zEkvg',
#   'izy8E4UBimE7927zEkvg',
#   'jDy8E4UBimE7927zEkvg',
#   'jTy8E4UBimE7927zEkvg',
#   'jjy8E4UBimE7927zEkvg',
#   'jzy8E4UBimE7927zEkvg',
#   'kDy8E4UBimE7927zEkvg',
#   'kTy8E4UBimE7927zEkvg',
#   'kjy8E4UBimE7927zEkvg',
#   'kzy8E4UBimE7927zEkvg',
#   'lDy8E4UBimE7927zEkvg',
#   'lTy8E4UBimE7927zEkvg',
#   'ljy8E4UBimE7927zEkvg',
#   'lzy8E4UBimE7927zEkvg',
#   'mDy8E4UBimE7927zEkvg',
#   'mTy8E4UBimE7927zEkvg',
#   'mjy8E4UBimE7927zEkvg',
#   'mzy8E4UBimE7927zEkvg',
#   'nDy8E4UBimE7927zEkvg',
#   'nTy8E4UBimE7927zEkvg',
#   'njy8E4UBimE7927zEkvg',
#   'nzy8E4UBimE7927zEkvg',
#   'oDy8E4UBimE7927zEkvg',
#   'oTy8E4UBimE7927zEkvg',
#   'ojy8E4UBimE7927zEkvg',
#   'ozy8E4UBimE7927zEkvg',
#   'pDy8E4UBimE7927zEkvg',
#   'pTy8E4UBimE7927zEkvg',
#   'pjy8E4UBimE7927zEkvg',
#   'pzy8E4UBimE7927zEkvg',
#   'qDy8E4UBimE7927zEkvg',
#   'qTy8E4UBimE7927zEkvg',
#   'qjy8E4UBimE7927zEkvg',
#   'qzy8E4UBimE7927zEkvg',
#   'rDy8E4UBimE7927zEkvg',
#   'rTy8E4UBimE7927zEkvg',
#   'rjy8E4UBimE7927zEkvg',
#   'rzy8E4UBimE7927zEkvg',
#   'sDy8E4UBimE7927zEkvg',
#   'sTy8E4UBimE7927zEkvg',
#   'sjy8E4UBimE7927zEkvg',
#   'szy8E4UBimE7927zEkvg',
#   'tDy8E4UBimE7927zEkvg',
#   'tTy8E4UBimE7927zEkvg',
#   'tjy8E4UBimE7927zEkvg',
#   'tzy8E4UBimE7927zEkvg',
#   'uDy8E4UBimE7927zEkvg',
#   'uTy8E4UBimE7927zEkvg',
#   'ujy8E4UBimE7927zEkvg',
#   'uzy8E4UBimE7927zEkvg',
#   'vDy8E4UBimE7927zEkvg',
#   'vTy8E4UBimE7927zEkvg',
#   'vjy8E4UBimE7927zEkvg',
#   'vzy8E4UBimE7927zEkvg',
#   'wDy8E4UBimE7927zEkvg',
#   'wTy8E4UBimE7927zEkvg',
#   'wjy8E4UBimE7927zEkvg',
#   'wzy8E4UBimE7927zEkvg',
#   'xDy8E4UBimE7927zEkvg',
#   'xTy8E4UBimE7927zEkvg',
#   'xjy8E4UBimE7927zEkvg',
#   'xzy8E4UBimE7927zEkvg',
#   'yDy8E4UBimE7927zEkvg',
#   'yTy8E4UBimE7927zEkvg',
#   'yjy8E4UBimE7927zEkvg',
#   'yzy8E4UBimE7927zEkvg',
#   'zDy8E4UBimE7927zEkvg',
#   'zTy8E4UBimE7927zEkvg',
#   'zjy8E4UBimE7927zEkvg',
#   'zzy8E4UBimE7927zEkvg',
#   '0Dy8E4UBimE7927zEkvg',
#   '0Ty8E4UBimE7927zEkvg',
#   '0jy8E4UBimE7927zEkvg',
#   '0zy8E4UBimE7927zEkvg',
#   '1Dy8E4UBimE7927zEkvg',
#   '1Ty8E4UBimE7927zEkvg',
#   '1jy8E4UBimE7927zEkvg',
#   '1zy8E4UBimE7927zEkvg',
#   '2Dy8E4UBimE7927zEkvg',
#   '2Ty8E4UBimE7927zEkvg',
#   '2jy8E4UBimE7927zEkvg',
#   '2zy8E4UBimE7927zEkvg',
#   '3Dy8E4UBimE7927zEkvg',
#   '3Ty8E4UBimE7927zEkvg',
#   '3jy8E4UBimE7927zEkvg',
#   '3zy8E4UBimE7927zEkvg',
#   '4Dy8E4UBimE7927zEkvg',
#   '4Ty8E4UBimE7927zEkvg',
#   '4jy8E4UBimE7927zEkvg',
#   '4zy8E4UBimE7927zEkvg',
#   '5Dy8E4UBimE7927zEkvg',
#   '5Ty8E4UBimE7927zEkvg',
#   '5jy8E4UBimE7927zEkvg',
#   '5zy8E4UBimE7927zEkvg',
#   '6Dy8E4UBimE7927zEkvg',
#   '6Ty8E4UBimE7927zEkvg',
#   '6jy8E4UBimE7927zEkvg',
#   '6zy8E4UBimE7927zEkvg',
#   '7Dy8E4UBimE7927zEkvg',
#   '7Ty8E4UBimE7927zEkvg',
#   '7jy8E4UBimE7927zEkvg',
#   '7zy8E4UBimE7927zEkvg',
#   '8Dy8E4UBimE7927zEkvg',
#   '8Ty8E4UBimE7927zEkvg',
#   '8jy8E4UBimE7927zEkvg',
#   '8zy8E4UBimE7927zEkvg',
#   '9Dy8E4UBimE7927zEkvg',
#   '9Ty8E4UBimE7927zEkvg',
#   '9jy8E4UBimE7927zEkvg',
#   '9zy8E4UBimE7927zEkvg',
#   '-Dy8E4UBimE7927zEkvg',
#   '-Ty8E4UBimE7927zEkvg',
#   '-jy8E4UBimE7927zEkvg',
#   '-zy8E4UBimE7927zEkvg',
#   '_Dy8E4UBimE7927zEkvg',
#   '_Ty8E4UBimE7927zEkvg',
#   '_jy8E4UBimE7927zEkvg',
#   '_zy8E4UBimE7927zEkvg',
#   'ADy8E4UBimE7927zEkzg',
#   'ATy8E4UBimE7927zEkzg',
#   'Ajy8E4UBimE7927zEkzg',
#   'Azy8E4UBimE7927zEkzg',
#   'BDy8E4UBimE7927zEkzg',
#   'BTy8E4UBimE7927zEkzg',
#   'Bjy8E4UBimE7927zEkzg',
#   'Bzy8E4UBimE7927zEkzg',
#   'CDy8E4UBimE7927zEkzg',
#   'CTy8E4UBimE7927zEkzg',
#   'Cjy8E4UBimE7927zEkzg',
#   'Czy8E4UBimE7927zEkzg',
#   'DDy8E4UBimE7927zEkzg',
#   'DTy8E4UBimE7927zEkzg',
#   'Djy8E4UBimE7927zEkzg',
#   'Dzy8E4UBimE7927zEkzg',
#   'EDy8E4UBimE7927zEkzg',
#   'ETy8E4UBimE7927zEkzg',
#   'Ejy8E4UBimE7927zEkzg',
#   'Ezy8E4UBimE7927zEkzg',
#   'FDy8E4UBimE7927zEkzg',
#   'FTy8E4UBimE7927zEkzg',
#   'Fjy8E4UBimE7927zEkzg',
#   'Fzy8E4UBimE7927zEkzg',
#   'GDy8E4UBimE7927zEkzg',
#   'GTy8E4UBimE7927zEkzg',
#   'Gjy8E4UBimE7927zEkzg',
#   'Gzy8E4UBimE7927zEkzg',
#   'HDy8E4UBimE7927zEkzg',
#   'HTy8E4UBimE7927zEkzg',
#   'Hjy8E4UBimE7927zEkzg',
#   'Hzy8E4UBimE7927zEkzg',
#   'IDy8E4UBimE7927zEkzg',
#   'ITy8E4UBimE7927zEkzg',
#   'Ijy8E4UBimE7927zEkzg',
#   'Izy8E4UBimE7927zEkzg',
#   'JDy8E4UBimE7927zEkzg',
#   'JTy8E4UBimE7927zEkzg',
#   'Jjy8E4UBimE7927zEkzg',
#   'Jzy8E4UBimE7927zEkzg',
#   'KDy8E4UBimE7927zEkzh',
#   'KTy8E4UBimE7927zEkzh',
#   'Kjy8E4UBimE7927zEkzh',
#   'Kzy8E4UBimE7927zEkzh',
#   'LDy8E4UBimE7927zEkzh',
#   'LTy8E4UBimE7927zEkzh',
#   'Ljy8E4UBimE7927zEkzh',
#   'Lzy8E4UBimE7927zEkzh',
#   'MDy8E4UBimE7927zEkzh',
#   'MTy8E4UBimE7927zEkzh',
#   'Mjy8E4UBimE7927zEkzh',
#   'Mzy8E4UBimE7927zEkzh',
#   'NDy8E4UBimE7927zEkzh',
#   'NTy8E4UBimE7927zEkzh',
#   'Njy8E4UBimE7927zEkzh',
#   'Nzy8E4UBimE7927zEkzh',
#   'ODy8E4UBimE7927zEkzh',
#   'OTy8E4UBimE7927zEkzh',
#   'Ojy8E4UBimE7927zEkzh',
#   'Ozy8E4UBimE7927zEkzh',
#   'PDy8E4UBimE7927zEkzh',
#   'PTy8E4UBimE7927zEkzh',
#   'Pjy8E4UBimE7927zEkzh',
#   'Pzy8E4UBimE7927zEkzh',
#   'QDy8E4UBimE7927zEkzh',
#   'QTy8E4UBimE7927zEkzh',
#   'Qjy8E4UBimE7927zEkzh',
#   'Qzy8E4UBimE7927zEkzh',
#   'RDy8E4UBimE7927zEkzh',
#   'RTy8E4UBimE7927zEkzh',
#   'Rjy8E4UBimE7927zEkzh',
#   'Rzy8E4UBimE7927zEkzh',
#   'SDy8E4UBimE7927zEkzh',
#   ...]}

# %%
delete_res = es_mgr.delete_document(collection_name = "meow", doc_id='Yzy8E4UBimE7927zEki1')
# Out:
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'elasticsearch'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
delete_res
# Out:
# {'response': '200',
#  'api_resp': ObjectApiResponse({'_index': 'meow', '_id': 'Yzy8E4UBimE7927zEki1', '_version': 2, 'result': 'deleted', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1002, '_primary_term': 1})}
